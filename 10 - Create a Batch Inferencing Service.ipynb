# %% [markdown]
# # Create a Batch Inferencing Service
#
# Imagine a health clinic takes patient measurements all day, saving the details for each patient in a separate file. Then overnight, the diabetes prediction model can be used to process all of the day's patient data as a batch, generating predictions that will be waiting the following morning so that the clinic can follow up with patients who are predicted to be at risk of diabetes. With Azure Machine Learning, you can accomplish this by creating a *batch inferencing pipeline*; and that's what you'll implement in this exercise.

# %% [markdown]
# ## Connect to your workspace
#
# To get started, connect to your workspace.
#
# > **Note**: If you haven't already established an authenticated session with your Azure subscription, you'll be prompted to authenticate by clicking a link, entering an authentication code, and signing into Azure.

# %%
import azureml.core
from azureml.core import Workspace

# Load the workspace from the saved config file
ws = Workspace.from_config()
print('Ready to use Azure ML {} to work with {}'.format(azureml.core.VERSION, ws.name))
# Out:
# Ready to use Azure ML 1.27.0 to work with aml-revision

# %% [markdown]
# ## Train and register a model
#
# Now let's train and register a model to deploy in a batch inferencing pipeline.

# %%
from azureml.core import Experiment
from azureml.core import Model
import pandas as pd
import numpy as np
import joblib
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

# Create an Azure ML experiment in your workspace
experiment = Experiment(workspace=ws, name='mslearn-train-diabetes')
run = experiment.start_logging()
print("Starting experiment:", experiment.name)

# load the diabetes dataset
print("Loading Data...")
diabetes = pd.read_csv('data/diabetes.csv')

# Separate features and labels
X, y = diabetes[['Pregnancies','PlasmaGlucose','DiastolicBloodPressure','TricepsThickness','SerumInsulin','BMI','DiabetesPedigree','Age']].values, diabetes['Diabetic'].values

# Split data into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=0)

# Train a decision tree model
print('Training a decision tree model')
model = DecisionTreeClassifier().fit(X_train, y_train)

# calculate accuracy
y_hat = model.predict(X_test)
acc = np.average(y_hat == y_test)
print('Accuracy:', acc)
run.log('Accuracy', np.float(acc))

# calculate AUC
y_scores = model.predict_proba(X_test)
auc = roc_auc_score(y_test,y_scores[:,1])
print('AUC: ' + str(auc))
run.log('AUC', np.float(auc))

# Save the trained model
model_file = 'diabetes_model.pkl'
joblib.dump(value=model, filename=model_file)
run.upload_file(name = 'outputs/' + model_file, path_or_stream = './' + model_file)

# Complete the run
run.complete()

# Register the model
run.register_model(model_path='outputs/diabetes_model.pkl', model_name='diabetes_model',
                   tags={'Training context':'Inline Training'},
                   properties={'AUC': run.get_metrics()['AUC'], 'Accuracy': run.get_metrics()['Accuracy']})

print('Model trained and registered.')
# Out:
# Starting experiment: mslearn-train-diabetes
# Loading Data...
# Training a decision tree model
# Accuracy: 0.894
# AUC: 0.8810935867456092
# Model trained and registered.

# %% [markdown]
# ## Generate and upload batch data
#
# Since we don't actually have a fully staffed clinic with patients from whom to get new data for this exercise, you'll generate a random sample from our diabetes CSV file, upload that data to a datastore in the Azure Machine Learning workspace, and register a dataset for it.

# %%
from azureml.core import Datastore, Dataset
import pandas as pd
import os

# Set default data store
ws.set_default_datastore('workspaceblobstore')
default_ds = ws.get_default_datastore()

# Enumerate all datastores, indicating which is the default
for ds_name in ws.datastores:
    print(ds_name, "- Default =", ds_name == default_ds.name)

# Load the diabetes data
diabetes = pd.read_csv('data/diabetes2.csv')
# Get a 100-item sample of the feature columns (not the diabetic label)
sample = diabetes[['Pregnancies','PlasmaGlucose','DiastolicBloodPressure','TricepsThickness','SerumInsulin','BMI','DiabetesPedigree','Age']].sample(n=100).values

# Create a folder
batch_folder = './batch-data'
os.makedirs(batch_folder, exist_ok=True)
print("Folder created!")

# Save each sample as a separate file
print("Saving files...")
for i in range(100):
    fname = str(i+1) + '.csv'
    sample[i].tofile(os.path.join(batch_folder, fname), sep=",")
print("files saved!")

# Upload the files to the default datastore
print("Uploading files to datastore...")
default_ds = ws.get_default_datastore()
default_ds.upload(src_dir="batch-data", target_path="batch-data", overwrite=True, show_progress=True)

# Register a dataset for the input data
batch_data_set = Dataset.File.from_files(path=(default_ds, 'batch-data/'), validate=False)
try:
    batch_data_set = batch_data_set.register(workspace=ws, 
                                             name='batch-data',
                                             description='batch data',
                                             create_new_version=True)
except Exception as ex:
    print(ex)

print("Done!")
# Out:
# workspaceblobstore - Default = True
# workspacefilestore - Default = False
# Folder created!
# Saving files...
# files saved!
# Uploading files to datastore...
# Uploading an estimated of 100 files
# Uploading batch-data/1.csv
# Uploaded batch-data/1.csv, 1 files out of an estimated total of 100
# Uploading batch-data/10.csv
# Uploaded batch-data/10.csv, 2 files out of an estimated total of 100
# Uploading batch-data/100.csv
# Uploaded batch-data/100.csv, 3 files out of an estimated total of 100
# Uploading batch-data/11.csv
# Uploaded batch-data/11.csv, 4 files out of an estimated total of 100
# Uploading batch-data/12.csv
# Uploaded batch-data/12.csv, 5 files out of an estimated total of 100
# Uploading batch-data/13.csv
# Uploaded batch-data/13.csv, 6 files out of an estimated total of 100
# Uploading batch-data/14.csv
# Uploaded batch-data/14.csv, 7 files out of an estimated total of 100
# Uploading batch-data/15.csv
# Uploaded batch-data/15.csv, 8 files out of an estimated total of 100
# Uploading batch-data/16.csv
# Uploaded batch-data/16.csv, 9 files out of an estimated total of 100
# Uploading batch-data/17.csv
# Uploaded batch-data/17.csv, 10 files out of an estimated total of 100
# Uploading batch-data/18.csv
# Uploaded batch-data/18.csv, 11 files out of an estimated total of 100
# Uploading batch-data/19.csv
# Uploaded batch-data/19.csv, 12 files out of an estimated total of 100
# Uploading batch-data/2.csv
# Uploaded batch-data/2.csv, 13 files out of an estimated total of 100
# Uploading batch-data/20.csv
# Uploaded batch-data/20.csv, 14 files out of an estimated total of 100
# Uploading batch-data/21.csv
# Uploaded batch-data/21.csv, 15 files out of an estimated total of 100
# Uploading batch-data/22.csv
# Uploaded batch-data/22.csv, 16 files out of an estimated total of 100
# Uploading batch-data/23.csv
# Uploaded batch-data/23.csv, 17 files out of an estimated total of 100
# Uploading batch-data/24.csv
# Uploaded batch-data/24.csv, 18 files out of an estimated total of 100
# Uploading batch-data/25.csv
# Uploaded batch-data/25.csv, 19 files out of an estimated total of 100
# Uploading batch-data/26.csv
# Uploaded batch-data/26.csv, 20 files out of an estimated total of 100
# Uploading batch-data/27.csv
# Uploaded batch-data/27.csv, 21 files out of an estimated total of 100
# Uploading batch-data/28.csv
# Uploaded batch-data/28.csv, 22 files out of an estimated total of 100
# Uploading batch-data/29.csv
# Uploaded batch-data/29.csv, 23 files out of an estimated total of 100
# Uploading batch-data/3.csv
# Uploaded batch-data/3.csv, 24 files out of an estimated total of 100
# Uploading batch-data/30.csv
# Uploaded batch-data/30.csv, 25 files out of an estimated total of 100
# Uploading batch-data/31.csv
# Uploaded batch-data/31.csv, 26 files out of an estimated total of 100
# Uploading batch-data/32.csv
# Uploaded batch-data/32.csv, 27 files out of an estimated total of 100
# Uploading batch-data/33.csv
# Uploaded batch-data/33.csv, 28 files out of an estimated total of 100
# Uploading batch-data/34.csv
# Uploaded batch-data/34.csv, 29 files out of an estimated total of 100
# Uploading batch-data/35.csv
# Uploaded batch-data/35.csv, 30 files out of an estimated total of 100
# Uploading batch-data/36.csv
# Uploaded batch-data/36.csv, 31 files out of an estimated total of 100
# Uploading batch-data/37.csv
# Uploaded batch-data/37.csv, 32 files out of an estimated total of 100
# Uploading batch-data/38.csv
# Uploaded batch-data/38.csv, 33 files out of an estimated total of 100
# Uploading batch-data/39.csv
# Uploaded batch-data/39.csv, 34 files out of an estimated total of 100
# Uploading batch-data/4.csv
# Uploaded batch-data/4.csv, 35 files out of an estimated total of 100
# Uploading batch-data/40.csv
# Uploaded batch-data/40.csv, 36 files out of an estimated total of 100
# Uploading batch-data/41.csv
# Uploaded batch-data/41.csv, 37 files out of an estimated total of 100
# Uploading batch-data/42.csv
# Uploaded batch-data/42.csv, 38 files out of an estimated total of 100
# Uploading batch-data/43.csv
# Uploaded batch-data/43.csv, 39 files out of an estimated total of 100
# Uploading batch-data/44.csv
# Uploaded batch-data/44.csv, 40 files out of an estimated total of 100
# Uploading batch-data/45.csv
# Uploaded batch-data/45.csv, 41 files out of an estimated total of 100
# Uploading batch-data/46.csv
# Uploaded batch-data/46.csv, 42 files out of an estimated total of 100
# Uploading batch-data/47.csv
# Uploaded batch-data/47.csv, 43 files out of an estimated total of 100
# Uploading batch-data/49.csv
# Uploaded batch-data/49.csv, 44 files out of an estimated total of 100
# Uploading batch-data/5.csv
# Uploaded batch-data/5.csv, 45 files out of an estimated total of 100
# Uploading batch-data/50.csv
# Uploaded batch-data/50.csv, 46 files out of an estimated total of 100
# Uploading batch-data/48.csv
# Uploaded batch-data/48.csv, 47 files out of an estimated total of 100
# Uploading batch-data/51.csv
# Uploaded batch-data/51.csv, 48 files out of an estimated total of 100
# Uploading batch-data/52.csv
# Uploaded batch-data/52.csv, 49 files out of an estimated total of 100
# Uploading batch-data/53.csv
# Uploaded batch-data/53.csv, 50 files out of an estimated total of 100
# Uploading batch-data/54.csv
# Uploaded batch-data/54.csv, 51 files out of an estimated total of 100
# Uploading batch-data/55.csv
# Uploaded batch-data/55.csv, 52 files out of an estimated total of 100
# Uploading batch-data/56.csv
# Uploaded batch-data/56.csv, 53 files out of an estimated total of 100
# Uploading batch-data/57.csv
# Uploaded batch-data/57.csv, 54 files out of an estimated total of 100
# Uploading batch-data/58.csv
# Uploaded batch-data/58.csv, 55 files out of an estimated total of 100
# Uploading batch-data/59.csv
# Uploaded batch-data/59.csv, 56 files out of an estimated total of 100
# Uploading batch-data/6.csv
# Uploaded batch-data/6.csv, 57 files out of an estimated total of 100
# Uploading batch-data/60.csv
# Uploaded batch-data/60.csv, 58 files out of an estimated total of 100
# Uploading batch-data/61.csv
# Uploaded batch-data/61.csv, 59 files out of an estimated total of 100
# Uploading batch-data/62.csv
# Uploaded batch-data/62.csv, 60 files out of an estimated total of 100
# Uploading batch-data/63.csv
# Uploaded batch-data/63.csv, 61 files out of an estimated total of 100
# Uploading batch-data/64.csv
# Uploaded batch-data/64.csv, 62 files out of an estimated total of 100
# Uploading batch-data/65.csv
# Uploaded batch-data/65.csv, 63 files out of an estimated total of 100
# Uploading batch-data/66.csv
# Uploaded batch-data/66.csv, 64 files out of an estimated total of 100
# Uploading batch-data/67.csv
# Uploaded batch-data/67.csv, 65 files out of an estimated total of 100
# Uploading batch-data/68.csv
# Uploaded batch-data/68.csv, 66 files out of an estimated total of 100
# Uploading batch-data/69.csv
# Uploaded batch-data/69.csv, 67 files out of an estimated total of 100
# Uploading batch-data/7.csv
# Uploaded batch-data/7.csv, 68 files out of an estimated total of 100
# Uploading batch-data/70.csv
# Uploaded batch-data/70.csv, 69 files out of an estimated total of 100
# Uploading batch-data/71.csv
# Uploaded batch-data/71.csv, 70 files out of an estimated total of 100
# Uploading batch-data/72.csv
# Uploaded batch-data/72.csv, 71 files out of an estimated total of 100
# Uploading batch-data/73.csv
# Uploaded batch-data/73.csv, 72 files out of an estimated total of 100
# Uploading batch-data/74.csv
# Uploaded batch-data/74.csv, 73 files out of an estimated total of 100
# Uploading batch-data/75.csv
# Uploaded batch-data/75.csv, 74 files out of an estimated total of 100
# Uploading batch-data/76.csv
# Uploaded batch-data/76.csv, 75 files out of an estimated total of 100
# Uploading batch-data/77.csv
# Uploaded batch-data/77.csv, 76 files out of an estimated total of 100
# Uploading batch-data/78.csv
# Uploaded batch-data/78.csv, 77 files out of an estimated total of 100
# Uploading batch-data/79.csv
# Uploaded batch-data/79.csv, 78 files out of an estimated total of 100
# Uploading batch-data/8.csv
# Uploaded batch-data/8.csv, 79 files out of an estimated total of 100
# Uploading batch-data/80.csv
# Uploaded batch-data/80.csv, 80 files out of an estimated total of 100
# Uploading batch-data/81.csv
# Uploaded batch-data/81.csv, 81 files out of an estimated total of 100
# Uploading batch-data/82.csv
# Uploaded batch-data/82.csv, 82 files out of an estimated total of 100
# Uploading batch-data/83.csv
# Uploaded batch-data/83.csv, 83 files out of an estimated total of 100
# Uploading batch-data/84.csv
# Uploaded batch-data/84.csv, 84 files out of an estimated total of 100
# Uploading batch-data/85.csv
# Uploaded batch-data/85.csv, 85 files out of an estimated total of 100
# Uploading batch-data/86.csv
# Uploaded batch-data/86.csv, 86 files out of an estimated total of 100
# Uploading batch-data/87.csv
# Uploaded batch-data/87.csv, 87 files out of an estimated total of 100
# Uploading batch-data/88.csv
# Uploaded batch-data/88.csv, 88 files out of an estimated total of 100
# Uploading batch-data/89.csv
# Uploaded batch-data/89.csv, 89 files out of an estimated total of 100
# Uploading batch-data/9.csv
# Uploaded batch-data/9.csv, 90 files out of an estimated total of 100
# Uploading batch-data/90.csv
# Uploaded batch-data/90.csv, 91 files out of an estimated total of 100
# Uploading batch-data/91.csv
# Uploaded batch-data/91.csv, 92 files out of an estimated total of 100
# Uploading batch-data/92.csv
# Uploaded batch-data/92.csv, 93 files out of an estimated total of 100
# Uploading batch-data/93.csv
# Uploaded batch-data/93.csv, 94 files out of an estimated total of 100
# Uploading batch-data/94.csv
# Uploaded batch-data/94.csv, 95 files out of an estimated total of 100
# Uploading batch-data/95.csv
# Uploaded batch-data/95.csv, 96 files out of an estimated total of 100
# Uploading batch-data/96.csv
# Uploaded batch-data/96.csv, 97 files out of an estimated total of 100
# Uploading batch-data/97.csv
# Uploaded batch-data/97.csv, 98 files out of an estimated total of 100
# Uploading batch-data/98.csv
# Uploaded batch-data/98.csv, 99 files out of an estimated total of 100
# Uploading batch-data/99.csv
# Uploaded batch-data/99.csv, 100 files out of an estimated total of 100
# Uploaded 100 files
# Done!

# %% [markdown]
# ## Create compute
#
# We'll need a compute context for the pipeline, so we'll use the following code to specify an Azure Machine Learning compute cluster (it will be created if it doesn't already exist).
#
# > **Important**: Change *your-compute-cluster* to the name of your compute cluster in the code below before running it! Cluster names must be globally unique names between 2 to 16 characters in length. Valid characters are letters, digits, and the - character.

# %%
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

cluster_name = "azCompCluster"

try:
    # Check for existing compute target
    inference_cluster = ComputeTarget(workspace=ws, name=cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    # If it doesn't already exist, create it
    try:
        compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_DS11_V2', max_nodes=2)
        inference_cluster = ComputeTarget.create(ws, cluster_name, compute_config)
        inference_cluster.wait_for_completion(show_output=True)
    except Exception as ex:
        print(ex)
# Out:
# Found existing cluster, use it.

# %% [markdown]
# ## Create a pipeline for batch inferencing
#
# Now we're ready to define the pipeline we'll use for batch inferencing. Our pipeline will need Python code to perform the batch inferencing, so let's create a folder where we can keep all the files used by the pipeline:

# %%
import os
# Create a folder for the experiment files
experiment_folder = 'batch_pipeline'
os.makedirs(experiment_folder, exist_ok=True)

print(experiment_folder)
# Out:
# batch_pipeline

# %% [markdown]
# Now we'll create a Python script to do the actual work, and save it in the pipeline folder:

# %%
# %%writefile $experiment_folder/batch_diabetes.py
import os
import numpy as np
from azureml.core import Model
import joblib


def init():
    # Runs when the pipeline step is initialized
    global model

    # load the model
    model_path = Model.get_model_path('diabetes_model')
    model = joblib.load(model_path)


def run(mini_batch):
    # This runs for each batch
    resultList = []

    # process each file in the batch
    for f in mini_batch:
        # Read the comma-delimited data into an array
        data = np.genfromtxt(f, delimiter=',')
        # Reshape into a 2-dimensional array for prediction (model expects multiple items)
        prediction = model.predict(data.reshape(1, -1))
        # Append prediction to results
        resultList.append("{}: {}".format(os.path.basename(f), prediction[0]))
    return resultList
# Out:
# Overwriting batch_pipeline/batch_diabetes.py

# %% [markdown]
# Next we'll define a run context that includes the dependencies required by the script

# %%
from azureml.core import Environment
from azureml.core.runconfig import DEFAULT_CPU_IMAGE
from azureml.core.runconfig import CondaDependencies

# Add dependencies required by the model
# For scikit-learn models, you need scikit-learn
# For parallel pipeline steps, you need azureml-core and azureml-dataprep[fuse]
cd = CondaDependencies.create(conda_packages=['scikit-learn','pip'],
                              pip_packages=['azureml-defaults','azureml-core','azureml-dataprep[fuse]'])

batch_env = Environment(name='batch_environment')
batch_env.python.conda_dependencies = cd
batch_env.docker.base_image = DEFAULT_CPU_IMAGE
print('Configuration ready.')
# Out:
# Configuration ready.

# %% [markdown]
# You're going to use a pipeline to run the batch prediction script, generate predictions from the input data, and save the results as a text file in the output folder. To do this, you can use a **ParallelRunStep**, which enables the batch data to be processed in parallel and the results collated in a single output file named *parallel_run_step.txt*.
#
# > **Note**: An *'enabled' is deprecated* warning may be displayed - you can ignore this.

# %%
from azureml.pipeline.steps import ParallelRunConfig, ParallelRunStep
from azureml.pipeline.core import PipelineData
from azureml.core.runconfig import DockerConfiguration

default_ds = ws.get_default_datastore()

output_dir = PipelineData(name='inferences', 
                          datastore=default_ds, 
                          output_path_on_compute='diabetes/results')

parallel_run_config = ParallelRunConfig(
    source_directory=experiment_folder,
    entry_script="batch_diabetes.py",
    mini_batch_size="5",
    error_threshold=10,
    output_action="append_row",
    environment=batch_env,
    compute_target=inference_cluster,
    node_count=2)

parallelrun_step = ParallelRunStep(
    name='batch-score-diabetes',
    parallel_run_config=parallel_run_config,
    inputs=[batch_data_set.as_named_input('diabetes_batch')],
    output=output_dir,
    arguments=[],
    allow_reuse=True
)

print('Steps defined')
# Out:
# 'enabled' is deprecated. Please use the azureml.core.runconfig.DockerConfiguration object with the 'use_docker' param instead.
# Steps defined

# %% [markdown]
# Now it's time to put the step into a pipeline, and run it.
#
# > **Note**: This may take some time!

# %%
from azureml.core import Experiment
from azureml.pipeline.core import Pipeline

pipeline = Pipeline(workspace=ws, steps=[parallelrun_step])
pipeline_run = Experiment(ws, 'mslearn-diabetes-batch').submit(pipeline)
pipeline_run.wait_for_completion(show_output=True)
# Out:
# Created step batch-score-diabetes [c581fa7c][5afcf187-f321-4537-9601-ce708e93cc52], (This step will run and generate new outputs)
# Submitted PipelineRun 59edae82-2160-4f83-8e4a-bee136d9c605
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/59edae82-2160-4f83-8e4a-bee136d9c605?wsid=/subscriptions/ecdf148e-e3eb-433a-9970-91b083980992/resourcegroups/aml-resources-2/workspaces/aml-revision&tid=798d0da9-368e-472e-83b1-e8d76c71d339
# PipelineRunId: 59edae82-2160-4f83-8e4a-bee136d9c605
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/59edae82-2160-4f83-8e4a-bee136d9c605?wsid=/subscriptions/ecdf148e-e3eb-433a-9970-91b083980992/resourcegroups/aml-resources-2/workspaces/aml-revision&tid=798d0da9-368e-472e-83b1-e8d76c71d339
# PipelineRun Status: Running
#
#
# StepRunId: 3566d9b7-7f46-43d9-b42f-74c7a53b44f5
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/3566d9b7-7f46-43d9-b42f-74c7a53b44f5?wsid=/subscriptions/ecdf148e-e3eb-433a-9970-91b083980992/resourcegroups/aml-resources-2/workspaces/aml-revision&tid=798d0da9-368e-472e-83b1-e8d76c71d339
# StepRun( batch-score-diabetes ) Status: NotStarted
# StepRun( batch-score-diabetes ) Status: Queued
# StepRun( batch-score-diabetes ) Status: Running
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
# 2021/05/31 23:45:02 Downloading source code...
# 2021/05/31 23:45:03 Finished downloading source code
# 2021/05/31 23:45:04 Creating Docker network: acb_default_network, driver: 'bridge'
# 2021/05/31 23:45:04 Successfully set up Docker network: acb_default_network
# 2021/05/31 23:45:04 Setting up Docker configuration...
# 2021/05/31 23:45:05 Successfully set up Docker configuration
# 2021/05/31 23:45:05 Logging in to registry: a17537c43d7f425dabe668516b2725e3.azurecr.io
# 2021/05/31 23:45:06 Successfully logged into a17537c43d7f425dabe668516b2725e3.azurecr.io
# 2021/05/31 23:45:06 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/05/31 23:45:06 Scanning for dependencies...
# 2021/05/31 23:45:07 Successfully scanned dependencies
# 2021/05/31 23:45:07 Launching container with name: acb_step_0
# Sending build context to Docker daemon  66.56kB
#
# Step 1/18 : FROM mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210301.v1@sha256:000d6c43f606ceaa67983790ca95c70fd741c364d8c2e3217a11d775b99741df
# mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210301.v1@sha256:000d6c43f606ceaa67983790ca95c70fd741c364d8c2e3217a11d775b99741df: Pulling from azureml/intelmpi2018.3-ubuntu16.04
# Digest: sha256:000d6c43f606ceaa67983790ca95c70fd741c364d8c2e3217a11d775b99741df
# Status: Downloaded newer image for mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210301.v1@sha256:000d6c43f606ceaa67983790ca95c70fd741c364d8c2e3217a11d775b99741df
#  ---> c942df5ba5d0
# Step 2/18 : USER root
#  ---> Running in 079086221dd0
# Removing intermediate container 079086221dd0
#  ---> 050b134d3287
# Step 3/18 : RUN mkdir -p $HOME/.cache
#  ---> Running in f94912978566
# Removing intermediate container f94912978566
#  ---> 22be7e7f9ed5
# Step 4/18 : WORKDIR /
#  ---> Running in 0c5c9c50285f
# Removing intermediate container 0c5c9c50285f
#  ---> bbee8fc1cc10
# Step 5/18 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> 1d5e1f345b15
# Step 6/18 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in c66db99debcf
# Removing intermediate container c66db99debcf
#  ---> 16873c928eaf
# Step 7/18 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> 4d59e6ae3e20
# Step 8/18 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_aa77a7252d8f04306986f9fa8a3997ad -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in 9e457b0dad55
# Collecting package metadata (repodata.json): ...working...
# done
# Solving environment: ...working...
# done
#
# Downloading and Extracting Packages
#
# pip-20.2.4           | 2.0 MB    |            |   0%
# pip-20.2.4           | 2.0 MB    | 7          |   8%
# pip-20.2.4           | 2.0 MB    | ########## | 100%
# pip-20.2.4           | 2.0 MB    | ########## | 100%
#
# libgcc-ng-9.1.0      | 8.1 MB    |            |   0%
# libgcc-ng-9.1.0      | 8.1 MB    | ########1  |  82%
# libgcc-ng-9.1.0      | 8.1 MB    | ########## | 100%
#
# ncurses-6.0          | 907 KB    |            |   0%
# ncurses-6.0          | 907 KB    | ########## | 100%
# ncurses-6.0          | 907 KB    | ########## | 100%
#
# openssl-1.0.2u       | 3.1 MB    |            |   0%
# openssl-1.0.2u       | 3.1 MB    | ########## | 100%
# openssl-1.0.2u       | 3.1 MB    | ########## | 100%
#
# zlib-1.2.11          | 120 KB    |            |   0%
# zlib-1.2.11          | 120 KB    | ########## | 100%
#
# certifi-2020.6.20    | 160 KB    |            |   0%
# certifi-2020.6.20    | 160 KB    | ########## | 100%
#
# scipy-1.5.2          | 18.5 MB   |            |   0%
# scipy-1.5.2          | 18.5 MB   | ##8        |  28%
# scipy-1.5.2          | 18.5 MB   | ########5  |  86%
# scipy-1.5.2          | 18.5 MB   | ########## | 100%
#
# ca-certificates-2020 | 128 KB    |            |   0%
# ca-certificates-2020 | 128 KB    | ########## | 100%
#
# threadpoolctl-2.1.0  | 16 KB     |            |   0%
# threadpoolctl-2.1.0  | 16 KB     | ########## | 100%
#
# mkl_random-1.1.0     | 369 KB    |            |   0%
# mkl_random-1.1.0     | 369 KB    | ########## | 100%
# mkl_random-1.1.0     | 369 KB    | ########## | 100%
#
# mkl-2019.4           | 204.1 MB  |            |   0%
# mkl-2019.4           | 204.1 MB  | 3          |   3%
# mkl-2019.4           | 204.1 MB  | 8          |   8%
# mkl-2019.4           | 204.1 MB  | #3         |  13%
# mkl-2019.4           | 204.1 MB  | #8         |  18%
# mkl-2019.4           | 204.1 MB  | ##3        |  23%
# mkl-2019.4           | 204.1 MB  | ##8        |  28%
# mkl-2019.4           | 204.1 MB  | ###3       |  33%
# mkl-2019.4           | 204.1 MB  | ###8       |  39%
# mkl-2019.4           | 204.1 MB  | ####3      |  43%
# mkl-2019.4           | 204.1 MB  | ####8      |  49%
# mkl-2019.4           | 204.1 MB  | #####3     |  54%
# mkl-2019.4           | 204.1 MB  | #####8     |  59%
# mkl-2019.4           | 204.1 MB  | ######3    |  64%
# mkl-2019.4           | 204.1 MB  | ######9    |  69%
# mkl-2019.4           | 204.1 MB  | #######3   |  74%
# mkl-2019.4           | 204.1 MB  | #######8   |  78%
# mkl-2019.4           | 204.1 MB  | ########3  |  84%
# mkl-2019.4           | 204.1 MB  | ########8  |  89%
# mkl-2019.4           | 204.1 MB  | #########3 |  94%
# mkl-2019.4           | 204.1 MB  | #########8 |  99%
#
# mkl-2019.4           | 204.1 MB  | ########## | 100%
#
# mkl_fft-1.2.0        | 164 KB    |            |   0%
# mkl_fft-1.2.0        | 164 KB    | ########## | 100%
#
# joblib-0.17.0        | 205 KB    |            |   0%
# joblib-0.17.0        | 205 KB    | ########## | 100%
#
# libedit-3.1          | 171 KB    |            |   0%
# libedit-3.1          | 171 KB    | ########## | 100%
#
# sqlite-3.23.1        | 1.5 MB    |            |   0%
# sqlite-3.23.1        | 1.5 MB    | ########## | 100%
# sqlite-3.23.1        | 1.5 MB    | ########## | 100%
#
# readline-7.0         | 387 KB    |            |   0%
# readline-7.0         | 387 KB    | ########## | 100%
# readline-7.0         | 387 KB    | ########## | 100%
#
# mkl-service-2.3.0    | 208 KB    |            |   0%
# mkl-service-2.3.0    | 208 KB    | ########## | 100%
# mkl-service-2.3.0    | 208 KB    | ########## | 100%
#
# numpy-1.19.1         | 20 KB     |            |   0%
# numpy-1.19.1         | 20 KB     | ########## | 100%
#
# tk-8.6.10            | 3.2 MB    |            |   0%
# tk-8.6.10            | 3.2 MB    | ########## | 100%
# tk-8.6.10            | 3.2 MB    | ########## | 100%
#
# numpy-base-1.19.1    | 5.2 MB    |            |   0%
# numpy-base-1.19.1    | 5.2 MB    | ######4    |  64%
# numpy-base-1.19.1    | 5.2 MB    | ########## | 100%
# numpy-base-1.19.1    | 5.2 MB    | ########## | 100%
#
# intel-openmp-2020.2  | 947 KB    |            |   0%
# intel-openmp-2020.2  | 947 KB    | ########## | 100%
# intel-openmp-2020.2  | 947 KB    | ########## | 100%
#
# scikit-learn-0.23.2  | 6.9 MB    |            |   0%
# scikit-learn-0.23.2  | 6.9 MB    | ########   |  81%
# scikit-learn-0.23.2  | 6.9 MB    | ########## | 100%
#
# wheel-0.35.1         | 36 KB     |            |   0%
# wheel-0.35.1         | 36 KB     | ########## | 100%
# wheel-0.35.1         | 36 KB     | ########## | 100%
#
# libffi-3.2.1         | 52 KB     |            |   0%
# libffi-3.2.1         | 52 KB     | ########## | 100%
#
# xz-5.2.5             | 438 KB    |            |   0%
# xz-5.2.5             | 438 KB    | ########## | 100%
# xz-5.2.5             | 438 KB    | ########## | 100%
#
# python-3.6.2         | 27.0 MB   |            |   0%
# python-3.6.2         | 27.0 MB   | ##5        |  26%
# python-3.6.2         | 27.0 MB   | ######5    |  65%
# python-3.6.2         | 27.0 MB   | ########## | 100%
# python-3.6.2         | 27.0 MB   | ########## | 100%
#
# libstdcxx-ng-9.1.0   | 4.0 MB    |            |   0%
# libstdcxx-ng-9.1.0   | 4.0 MB    | ########## | 100%
# libstdcxx-ng-9.1.0   | 4.0 MB    | ########## | 100%
#
# libgfortran-ng-7.3.0 | 1.3 MB    |            |   0%
# libgfortran-ng-7.3.0 | 1.3 MB    | ########## | 100%
# libgfortran-ng-7.3.0 | 1.3 MB    | ########## | 100%
#
# setuptools-50.3.0    | 891 KB    |            |   0%
# setuptools-50.3.0    | 891 KB    | ########## | 100%
# setuptools-50.3.0    | 891 KB    | ########## | 100%
#
# blas-1.0             | 6 KB      |            |   0%
# blas-1.0             | 6 KB      | ########## | 100%
#
# six-1.15.0           | 13 KB     |            |   0%
# six-1.15.0           | 13 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Installing pip dependencies: ...working...
# Ran pip subprocess with arguments:
# ['/azureml-envs/azureml_aa77a7252d8f04306986f9fa8a3997ad/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv.z_jr_j9m.requirements.txt']
# Pip subprocess output:
# Collecting azureml-defaults~=1.27.0
#   Downloading azureml_defaults-1.27.0-py3-none-any.whl (3.1 kB)
# Collecting azureml-core~=1.27.0
#   Downloading azureml_core-1.27.0.post1-py3-none-any.whl (2.2 MB)
# Collecting azureml-dataprep[fuse]
#   Downloading azureml_dataprep-2.17.0-py3-none-any.whl (39.4 MB)
# Collecting werkzeug<=1.0.1,>=0.16.1
#   Downloading Werkzeug-1.0.1-py2.py3-none-any.whl (298 kB)
# Collecting gunicorn==19.9.0
#   Downloading gunicorn-19.9.0-py2.py3-none-any.whl (112 kB)
# Collecting azureml-dataset-runtime[fuse]~=1.27.0
#   Downloading azureml_dataset_runtime-1.27.0-py3-none-any.whl (3.4 kB)
# Collecting applicationinsights>=0.11.7
#   Downloading applicationinsights-0.11.10-py2.py3-none-any.whl (55 kB)
# Collecting flask==1.0.3
#   Downloading Flask-1.0.3-py2.py3-none-any.whl (92 kB)
# Collecting configparser==3.7.4
#   Downloading configparser-3.7.4-py2.py3-none-any.whl (22 kB)
# Collecting azureml-model-management-sdk==1.0.1b6.post1
#   Downloading azureml_model_management_sdk-1.0.1b6.post1-py2.py3-none-any.whl (130 kB)
# Collecting json-logging-py==0.2
#   Downloading json-logging-py-0.2.tar.gz (3.6 kB)
# Collecting urllib3>=1.23
#   Downloading urllib3-1.26.5-py2.py3-none-any.whl (138 kB)
# Collecting azure-mgmt-authorization<1.0.0,>=0.40.0
#   Downloading azure_mgmt_authorization-0.61.0-py2.py3-none-any.whl (94 kB)
# Collecting adal>=1.2.0
#   Downloading adal-1.2.7-py2.py3-none-any.whl (55 kB)
# Collecting requests<3.0.0,>=2.19.1
#   Downloading requests-2.25.1-py2.py3-none-any.whl (61 kB)
# Collecting msrestazure>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting azure-common<2.0.0,>=1.1.12
#   Downloading azure_common-1.1.27-py2.py3-none-any.whl (12 kB)
# Collecting msrest<1.0.0,>=0.5.1
#   Downloading msrest-0.6.21-py2.py3-none-any.whl (85 kB)
# Collecting pathspec<1.0.0
#   Downloading pathspec-0.8.1-py2.py3-none-any.whl (28 kB)
# Collecting pytz
#   Downloading pytz-2021.1-py2.py3-none-any.whl (510 kB)
# Collecting azure-mgmt-keyvault<7.0.0,>=0.40.0
#   Downloading azure_mgmt_keyvault-2.2.0-py2.py3-none-any.whl (89 kB)
# Collecting azure-mgmt-resource<15.0.0,>=1.2.1
#   Downloading azure_mgmt_resource-13.0.0-py2.py3-none-any.whl (1.3 MB)
# Collecting pyopenssl<21.0.0
#   Downloading pyOpenSSL-20.0.1-py2.py3-none-any.whl (54 kB)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Downloading azure_mgmt_containerregistry-8.0.0-py2.py3-none-any.whl (663 kB)
# Collecting docker<5.0.0
#   Downloading docker-4.4.4-py2.py3-none-any.whl (147 kB)
# Collecting jsonpickle<3.0.0
#   Downloading jsonpickle-2.0.0-py2.py3-none-any.whl (37 kB)
# Collecting azure-graphrbac<1.0.0,>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting PyJWT<3.0.0
#   Downloading PyJWT-2.1.0-py3-none-any.whl (16 kB)
# Collecting jmespath<1.0.0
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting SecretStorage<4.0.0
#   Downloading SecretStorage-3.3.1-py3-none-any.whl (15 kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<4.0.0
#   Downloading cryptography-3.4.7-cp36-abi3-manylinux2014_x86_64.whl (3.2 MB)
# Collecting python-dateutil<3.0.0,>=2.7.3
#   Downloading python_dateutil-2.8.1-py2.py3-none-any.whl (227 kB)
# Collecting ndg-httpsclient
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting azure-mgmt-storage<16.0.0,>=1.5.0
#   Downloading azure_mgmt_storage-11.2.0-py2.py3-none-any.whl (547 kB)
# Collecting contextlib2<1.0.0
#   Downloading contextlib2-0.6.0.post1-py2.py3-none-any.whl (9.8 kB)
# Collecting ruamel.yaml<0.17.5,>=0.15.35
#   Downloading ruamel.yaml-0.17.4-py3-none-any.whl (101 kB)
# Collecting azureml-dataprep-native<36.0.0,>=35.0.0
#   Downloading azureml_dataprep_native-35.0.0-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Collecting cloudpickle<2.0.0,>=1.1.0
#   Downloading cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Collecting azure-identity<1.5.0,>=1.2.0
#   Downloading azure_identity-1.4.1-py2.py3-none-any.whl (86 kB)
# Collecting azureml-dataprep-rslex<1.16.0a,>=1.15.0dev0
#   Downloading azureml_dataprep_rslex-1.15.0-cp36-cp36m-manylinux1_x86_64.whl (84.0 MB)
# Collecting dotnetcore2<3.0.0,>=2.1.14
#   Downloading dotnetcore2-2.1.20-py3-none-manylinux1_x86_64.whl (28.7 MB)
# Collecting fusepy<4.0.0,>=3.0.1; extra == "fuse"
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
# Requirement already satisfied, skipping upgrade: numpy!=1.19.3; sys_platform == "linux" in /azureml-envs/azureml_aa77a7252d8f04306986f9fa8a3997ad/lib/python3.6/site-packages (from azureml-dataset-runtime[fuse]~=1.27.0->azureml-defaults~=1.27.0->-r /azureml-environment-setup/condaenv.z_jr_j9m.requirements.txt (line 1)) (1.19.1)
# Collecting pyarrow<2.0.0,>=0.17.0
#   Downloading pyarrow-1.0.1-cp36-cp36m-manylinux2014_x86_64.whl (17.3 MB)
# Collecting click>=5.1
#   Downloading click-8.0.1-py3-none-any.whl (97 kB)
# Collecting Jinja2>=2.10
#   Downloading Jinja2-3.0.1-py3-none-any.whl (133 kB)
# Collecting itsdangerous>=0.24
#   Downloading itsdangerous-2.0.1-py3-none-any.whl (18 kB)
# Requirement already satisfied, skipping upgrade: six>=1.10 in /azureml-envs/azureml_aa77a7252d8f04306986f9fa8a3997ad/lib/python3.6/site-packages (from azureml-model-management-sdk==1.0.1b6.post1->azureml-defaults~=1.27.0->-r /azureml-environment-setup/condaenv.z_jr_j9m.requirements.txt (line 1)) (1.15.0)
# Collecting pandas>=0.20.2
#   Downloading pandas-1.1.5-cp36-cp36m-manylinux1_x86_64.whl (9.5 MB)
# Collecting liac-arff>=2.1.1
#   Downloading liac-arff-2.5.0.tar.gz (13 kB)
# Collecting dill>=0.2.7.1
#   Downloading dill-0.3.3-py2.py3-none-any.whl (81 kB)
# Collecting chardet<5,>=3.0.2
#   Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
# Collecting idna<3,>=2.5
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /azureml-envs/azureml_aa77a7252d8f04306986f9fa8a3997ad/lib/python3.6/site-packages (from requests<3.0.0,>=2.19.1->azureml-core~=1.27.0->-r /azureml-environment-setup/condaenv.z_jr_j9m.requirements.txt (line 2)) (2020.6.20)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting azure-mgmt-core<2.0.0,>=1.2.0
#   Downloading azure_mgmt_core-1.2.2-py2.py3-none-any.whl (21 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-1.0.1-py2.py3-none-any.whl (68 kB)
# Collecting importlib-metadata; python_version < "3.8"
#   Downloading importlib_metadata-4.4.0-py3-none-any.whl (17 kB)
# Collecting jeepney>=0.6
#   Downloading jeepney-0.6.0-py3-none-any.whl (45 kB)
# Collecting cffi>=1.12
#   Downloading cffi-1.14.5-cp36-cp36m-manylinux1_x86_64.whl (401 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.10"
#   Downloading ruamel.yaml.clib-0.2.2-cp36-cp36m-manylinux1_x86_64.whl (549 kB)
# Collecting azure-core<2.0.0,>=1.0.0
#   Downloading azure_core-1.14.0-py2.py3-none-any.whl (136 kB)
# Collecting msal-extensions~=0.2.2
#   Downloading msal_extensions-0.2.2-py2.py3-none-any.whl (15 kB)
# Collecting msal<2.0.0,>=1.3.0
#   Downloading msal-1.12.0-py2.py3-none-any.whl (66 kB)
# Collecting distro>=1.2.0
#   Downloading distro-1.5.0-py2.py3-none-any.whl (18 kB)
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.0.1-cp36-cp36m-manylinux2010_x86_64.whl (30 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Collecting typing-extensions>=3.6.4; python_version < "3.8"
#   Downloading typing_extensions-3.10.0.0-py3-none-any.whl (26 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.4.1-py3-none-any.whl (5.2 kB)
# Collecting pycparser
#   Downloading pycparser-2.20-py2.py3-none-any.whl (112 kB)
# Collecting portalocker~=1.0; platform_system != "Windows"
#   Downloading portalocker-1.7.1-py2.py3-none-any.whl (10 kB)
# Building wheels for collected packages: json-logging-py, fusepy, liac-arff
#   Building wheel for json-logging-py (setup.py): started
#   Building wheel for json-logging-py (setup.py): finished with status 'done'
#   Created wheel for json-logging-py: filename=json_logging_py-0.2-py3-none-any.whl size=3924 sha256=8799121191658627dcd995905247666da72c66bfe116179da83c556df359476b
#   Stored in directory: /root/.cache/pip/wheels/e2/1d/52/535a274b9c2ce7d4064838f2bdb62013801281ef7d7f21e2ee
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10504 sha256=d053e300473308423f650879b2f4d366896057843e334396f0ea2edb81d81fc2
#   Stored in directory: /root/.cache/pip/wheels/21/5c/83/1dd7e8a232d12227e5410120f4374b33adeb4037473105b079
#   Building wheel for liac-arff (setup.py): started
#   Building wheel for liac-arff (setup.py): finished with status 'done'
#   Created wheel for liac-arff: filename=liac_arff-2.5.0-py3-none-any.whl size=11730 sha256=f7cf8b91994acb91d7c660b981287a704e5e85f038532cf19c7f263acb3461a4
#   Stored in directory: /root/.cache/pip/wheels/53/ba/da/8562a6a6dbb428fd1ecc21053106df3948645cd991958f669b
# Successfully built json-logging-py fusepy liac-arff
# Installing collected packages: werkzeug, gunicorn, pyarrow, azureml-dataprep-native, cloudpickle, chardet, idna, urllib3, requests, azure-core, pycparser, cffi, cryptography, portalocker, PyJWT, msal, msal-extensions, azure-identity, azureml-dataprep-rslex, distro, dotnetcore2, fusepy, azureml-dataprep, azureml-dataset-runtime, applicationinsights, typing-extensions, zipp, importlib-metadata, click, MarkupSafe, Jinja2, itsdangerous, flask, python-dateutil, adal, isodate, oauthlib, requests-oauthlib, msrest, msrestazure, azure-common, azure-mgmt-authorization, backports.weakref, backports.tempfile, pathspec, pytz, azure-mgmt-keyvault, azure-mgmt-resource, pyopenssl, azure-mgmt-core, azure-mgmt-containerregistry, websocket-client, docker, jsonpickle, azure-graphrbac, jmespath, jeepney, SecretStorage, pyasn1, ndg-httpsclient, azure-mgmt-storage, contextlib2, ruamel.yaml.clib, ruamel.yaml, azureml-core, configparser, pandas, liac-arff, dill, azureml-model-management-sdk, json-logging-py, azureml-defaults
# Successfully installed Jinja2-3.0.1 MarkupSafe-2.0.1 PyJWT-2.1.0 SecretStorage-3.3.1 adal-1.2.7 applicationinsights-0.11.10 azure-common-1.1.27 azure-core-1.14.0 azure-graphrbac-0.61.1 azure-identity-1.4.1 azure-mgmt-authorization-0.61.0 azure-mgmt-containerregistry-8.0.0 azure-mgmt-core-1.2.2 azure-mgmt-keyvault-2.2.0 azure-mgmt-resource-13.0.0 azure-mgmt-storage-11.2.0 azureml-core-1.27.0.post1 azureml-dataprep-2.17.0 azureml-dataprep-native-35.0.0 azureml-dataprep-rslex-1.15.0 azureml-dataset-runtime-1.27.0 azureml-defaults-1.27.0 azureml-model-management-sdk-1.0.1b6.post1 backports.tempfile-1.0 backports.weakref-1.0.post1 cffi-1.14.5 chardet-4.0.0 click-8.0.1 cloudpickle-1.6.0 configparser-3.7.4 contextlib2-0.6.0.post1 cryptography-3.4.7 dill-0.3.3 distro-1.5.0 docker-4.4.4 dotnetcore2-2.1.20 flask-1.0.3 fusepy-3.0.1 gunicorn-19.9.0 idna-2.10 importlib-metadata-4.4.0 isodate-0.6.0 itsdangerous-2.0.1 jeepney-0.6.0 jmespath-0.10.0 json-logging-py-0.2 jsonpickle-2.0.0 liac-arff-2.5.0 msal-1.12.0 msal-extensions-0.2.2 msrest-0.6.21 msrestazure-0.6.4 ndg-httpsclient-0.5.1 oauthlib-3.1.0 pandas-1.1.5 pathspec-0.8.1 portalocker-1.7.1 pyarrow-1.0.1 pyasn1-0.4.8 pycparser-2.20 pyopenssl-20.0.1 python-dateutil-2.8.1 pytz-2021.1 requests-2.25.1 requests-oauthlib-1.3.0 ruamel.yaml-0.17.4 ruamel.yaml.clib-0.2.2 typing-extensions-3.10.0.0 urllib3-1.26.5 websocket-client-1.0.1 werkzeug-1.0.1 zipp-3.4.1
#
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate /azureml-envs/azureml_aa77a7252d8f04306986f9fa8a3997ad
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 4.10.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
# WARNING: /root/.conda/pkgs does not exist
# Removing intermediate container 9e457b0dad55
#  ---> b19f11b887b9
# Step 9/18 : ENV PATH /azureml-envs/azureml_aa77a7252d8f04306986f9fa8a3997ad/bin:$PATH
#  ---> Running in e6c0190dbb7f
# Removing intermediate container e6c0190dbb7f
#  ---> 70afc08578ca
# Step 10/18 : COPY azureml-environment-setup/send_conda_dependencies.py azureml-environment-setup/send_conda_dependencies.py
#  ---> c160b574458d
# Step 11/18 : COPY azureml-environment-setup/environment_context.json azureml-environment-setup/environment_context.json
#  ---> 8f1e13845fb3
# Step 12/18 : RUN python /azureml-environment-setup/send_conda_dependencies.py -p /azureml-envs/azureml_aa77a7252d8f04306986f9fa8a3997ad
#  ---> Running in cfb2eb32439e
# Report materialized dependencies for the environment
# Reading environment context
# Exporting conda environment
# Sending request with materialized conda environment details
# Successfully sent materialized environment details
# Removing intermediate container cfb2eb32439e
#  ---> 292c9c91ebc9
# Step 13/18 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_aa77a7252d8f04306986f9fa8a3997ad
#  ---> Running in 85e549cf06e2
# Removing intermediate container 85e549cf06e2
#  ---> 053bffe9c41b
# Step 14/18 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_aa77a7252d8f04306986f9fa8a3997ad/lib:$LD_LIBRARY_PATH
#  ---> Running in 5ca93b31b713
# Removing intermediate container 5ca93b31b713
#  ---> b5b74bd8c54c
# Step 15/18 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> 0360bf69330c
# Step 16/18 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in cfed9e596bb7
# Removing intermediate container cfed9e596bb7
#  ---> cf062e916b99
# Step 17/18 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in 3342008b2956
# Removing intermediate container 3342008b2956
#  ---> 491a8fcbdec6
# Step 18/18 : CMD ["bash"]
#  ---> Running in f9e9031a487a
# Removing intermediate container f9e9031a487a
#  ---> 4a5122caf260
# Successfully built 4a5122caf260
# Successfully tagged a17537c43d7f425dabe668516b2725e3.azurecr.io/azureml/azureml_30f73517ee346cfd8e80806a4c9e074e:latest
# Successfully tagged a17537c43d7f425dabe668516b2725e3.azurecr.io/azureml/azureml_30f73517ee346cfd8e80806a4c9e074e:1
# 2021/05/31 23:48:55 Successfully executed container: acb_step_0
# 2021/05/31 23:48:55 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/05/31 23:48:55 Pushing image: a17537c43d7f425dabe668516b2725e3.azurecr.io/azureml/azureml_30f73517ee346cfd8e80806a4c9e074e:1, attempt 1
# The push refers to repository [a17537c43d7f425dabe668516b2725e3.azurecr.io/azureml/azureml_30f73517ee346cfd8e80806a4c9e074e]
# bec0b09def2d: Preparing
# 56fbf29478fc: Preparing
# ea32d9bf7dcb: Preparing
# 4502d2a38e87: Preparing
# 5f030fc5622e: Preparing
# 8730a3b562dd: Preparing
# 429451f2949b: Preparing
# f559102f27dd: Preparing
# 00834b5f6c5b: Preparing
# 3f3f8889d538: Preparing
# 420340de7040: Preparing
# c3d9b0d7dd4c: Preparing
# 4441896e1280: Preparing
# a64fe594a899: Preparing
# 0d34930f20d5: Preparing
# 18c9012f327d: Preparing
# e4a0bf630548: Preparing
# 5276d2b930fc: Preparing
# e6feec0db89a: Preparing
# 697949baa658: Preparing
# 935c56d8b3f9: Preparing
# 429451f2949b: Waiting
# f559102f27dd: Waiting
# 00834b5f6c5b: Waiting
# 3f3f8889d538: Waiting
# 420340de7040: Waiting
# c3d9b0d7dd4c: Waiting
# 4441896e1280: Waiting
# a64fe594a899: Waiting
# 0d34930f20d5: Waiting
# 18c9012f327d: Waiting
# e4a0bf630548: Waiting
# 5276d2b930fc: Waiting
# e6feec0db89a: Waiting
# 697949baa658: Waiting
# 935c56d8b3f9: Waiting
# 8730a3b562dd: Waiting
# ea32d9bf7dcb: Pushed
# 4502d2a38e87: Pushed
# bec0b09def2d: Pushed
# 56fbf29478fc: Pushed
# 429451f2949b: Pushed
# 8730a3b562dd: Pushed
# f559102f27dd: Pushed
# 00834b5f6c5b: Pushed
# 3f3f8889d538: Pushed
# 420340de7040: Pushed
# c3d9b0d7dd4c: Pushed
# 18c9012f327d: Pushed
# 4441896e1280: Pushed
# 5276d2b930fc: Pushed
# e6feec0db89a: Pushed
# 697949baa658: Pushed
# 0d34930f20d5: Pushed
# a64fe594a899: Pushed
# 935c56d8b3f9: Pushed
# e4a0bf630548: Pushed
#
# 5f030fc5622e: Pushed
# 1: digest: sha256:a15edbde5d44bfd1d06eb7b2afed73173c328d34d1eea9d03e0c3fc97568b519 size: 4721
# 2021/05/31 23:51:38 Successfully pushed image: a17537c43d7f425dabe668516b2725e3.azurecr.io/azureml/azureml_30f73517ee346cfd8e80806a4c9e074e:1
# 2021/05/31 23:51:38 Executing step ID: acb_step_2. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/05/31 23:51:38 Pushing image: a17537c43d7f425dabe668516b2725e3.azurecr.io/azureml/azureml_30f73517ee346cfd8e80806a4c9e074e:latest, attempt 1
# The push refers to repository [a17537c43d7f425dabe668516b2725e3.azurecr.io/azureml/azureml_30f73517ee346cfd8e80806a4c9e074e]
# bec0b09def2d: Preparing
# 56fbf29478fc: Preparing
# ea32d9bf7dcb: Preparing
# 4502d2a38e87: Preparing
# 5f030fc5622e: Preparing
# 8730a3b562dd: Preparing
# 429451f2949b: Preparing
# f559102f27dd: Preparing
# 00834b5f6c5b: Preparing
# 3f3f8889d538: Preparing
# 420340de7040: Preparing
# c3d9b0d7dd4c: Preparing
# 4441896e1280: Preparing
# a64fe594a899: Preparing
# 0d34930f20d5: Preparing
# 18c9012f327d: Preparing
# e4a0bf630548: Preparing
# 5276d2b930fc: Preparing
# e6feec0db89a: Preparing
# 697949baa658: Preparing
# 935c56d8b3f9: Preparing
# 8730a3b562dd: Waiting
# 429451f2949b: Waiting
# f559102f27dd: Waiting
# 18c9012f327d: Waiting
# 00834b5f6c5b: Waiting
# 3f3f8889d538: Waiting
# e4a0bf630548: Waiting
# 420340de7040: Waiting
# 5276d2b930fc: Waiting
# c3d9b0d7dd4c: Waiting
# 4441896e1280: Waiting
# e6feec0db89a: Waiting
# a64fe594a899: Waiting
# 0d34930f20d5: Waiting
# 697949baa658: Waiting
# 935c56d8b3f9: Waiting
# 5f030fc5622e: Layer already exists
# 56fbf29478fc: Layer already exists
# ea32d9bf7dcb: Layer already exists
# 4502d2a38e87: Layer already exists
# bec0b09def2d: Layer already exists
# 00834b5f6c5b: Layer already exists
# 3f3f8889d538: Layer already exists
# 429451f2949b: Layer already exists
# 8730a3b562dd: Layer already exists
# c3d9b0d7dd4c: Layer already exists
# f559102f27dd: Layer already exists
# 420340de7040: Layer already exists
# 4441896e1280: Layer already exists
# a64fe594a899: Layer already exists
# 0d34930f20d5: Layer already exists
# e4a0bf630548: Layer already exists
# 18c9012f327d: Layer already exists
# 5276d2b930fc: Layer already exists
# e6feec0db89a: Layer already exists
# 935c56d8b3f9: Layer already exists
# 697949baa658: Layer already exists
# latest: digest: sha256:a15edbde5d44bfd1d06eb7b2afed73173c328d34d1eea9d03e0c3fc97568b519 size: 4721
# 2021/05/31 23:51:51 Successfully pushed image: a17537c43d7f425dabe668516b2725e3.azurecr.io/azureml/azureml_30f73517ee346cfd8e80806a4c9e074e:latest
# 2021/05/31 23:51:51 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 228.244933)
# 2021/05/31 23:51:51 Populating digests for step ID: acb_step_0...
# 2021/05/31 23:51:55 Successfully populated digests for step ID: acb_step_0
# 2021/05/31 23:51:55 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 163.674297)
# 2021/05/31 23:51:55 Step ID: acb_step_2 marked as successful (elapsed time in seconds: 13.174653)
# 2021/05/31 23:51:55 The following dependencies were found:
# 2021/05/31 23:51:55
# - image:
#     registry: a17537c43d7f425dabe668516b2725e3.azurecr.io
#     repository: azureml/azureml_30f73517ee346cfd8e80806a4c9e074e
#     tag: latest
#     digest: sha256:a15edbde5d44bfd1d06eb7b2afed73173c328d34d1eea9d03e0c3fc97568b519
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/intelmpi2018.3-ubuntu16.04
#     tag: 20210301.v1
#     digest: sha256:000d6c43f606ceaa67983790ca95c70fd741c364d8c2e3217a11d775b99741df
#   git: {}
# - image:
#     registry: a17537c43d7f425dabe668516b2725e3.azurecr.io
#     repository: azureml/azureml_30f73517ee346cfd8e80806a4c9e074e
#     tag: "1"
#     digest: sha256:a15edbde5d44bfd1d06eb7b2afed73173c328d34d1eea9d03e0c3fc97568b519
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/intelmpi2018.3-ubuntu16.04
#     tag: 20210301.v1
#     digest: sha256:000d6c43f606ceaa67983790ca95c70fd741c364d8c2e3217a11d775b99741df
#   git: {}
#
# Run ID: cc5 was successful after 6m54s
#
# Streaming azureml-logs/55_azureml-execution-tvmps_007a9e0585dac890f4ea395a1d78dd48ecd3c0948cfd67e525d20a46fc846d08_d.txt
# ========================================================================================================================
# 2021-05-31T23:57:13Z Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/aml-revision/azureml/3566d9b7-7f46-43d9-b42f-74c7a53b44f5/mounts/workspaceblobstore
# 2021-05-31T23:57:14Z Starting output-watcher...
# 2021-05-31T23:57:14Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2021-05-31T23:57:15Z Executing 'Copy ACR Details file' on 10.0.0.5
# 2021-05-31T23:57:15Z Executing 'Copy ACR Details file' on 10.0.0.4
# 2021-05-31T23:57:15Z Copy ACR Details file succeeded on 10.0.0.4. Output:
# >>>
# >>>
# 2021-05-31T23:57:16Z Copy ACR Details file succeeded on 10.0.0.5. Output:
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_4539de3ccb169db6707c8cade7afe14c
# 4007a89234b4: Pulling fs layer
# 5dfa26c6b9c9: Pulling fs layer
# 0ba7bf18aa40: Pulling fs layer
# 4c6ec688ebe3: Pulling fs layer
# 574f361512d6: Pulling fs layer
# db4d1e2d7079: Pulling fs layer
# e544ee0f522d: Pulling fs layer
# c655136086be: Pulling fs layer
# 2ec37f44090c: Pulling fs layer
# 5fba3bd4a2c4: Pulling fs layer
# 7e0ea9d0a1ab: Pulling fs layer
# da005f826951: Pulling fs layer
# ac4e1c91b241: Pulling fs layer
# efb648489c68: Pulling fs layer
# e5e2bb35fef1: Pulling fs layer
# 41f64f9d12ca: Pulling fs layer
# 404e390f8ac9: Pulling fs layer
# 00d1c09f699a: Pulling fs layer
# 4c6ec688ebe3: Waiting
# 574f361512d6: Waiting
# db4d1e2d7079: Waiting
# e544ee0f522d: Waiting
# c655136086be: Waiting
# 2ec37f44090c: Waiting
# 5fba3bd4a2c4: Waiting
# 7e0ea9d0a1ab: Waiting
# da005f826951: Waiting
# ac4e1c91b241: Waiting
# efb648489c68: Waiting
# e5e2bb35fef1: Waiting
# 41f64f9d12ca: Waiting
# 404e390f8ac9: Waiting
# 00d1c09f699a: Waiting
# 5dfa26c6b9c9: Download complete
# 0ba7bf18aa40: Download complete
# 4c6ec688ebe3: Verifying Checksum
# 4c6ec688ebe3: Download complete
# 4007a89234b4: Verifying Checksum
# 4007a89234b4: Download complete
# db4d1e2d7079: Verifying Checksum
# db4d1e2d7079: Download complete
# e544ee0f522d: Verifying Checksum
# e544ee0f522d: Download complete
# 574f361512d6: Verifying Checksum
# 574f361512d6: Download complete
# 5fba3bd4a2c4: Verifying Checksum
# 5fba3bd4a2c4: Download complete
# 7e0ea9d0a1ab: Verifying Checksum
# 7e0ea9d0a1ab: Download complete
# c655136086be: Verifying Checksum
# c655136086be: Download complete
# da005f826951: Verifying Checksum
# da005f826951: Download complete
# ac4e1c91b241: Verifying Checksum
# ac4e1c91b241: Download complete
# e5e2bb35fef1: Verifying Checksum
# e5e2bb35fef1: Download complete
# 2ec37f44090c: Verifying Checksum
# 2ec37f44090c: Download complete
# 404e390f8ac9: Verifying Checksum
# 404e390f8ac9: Download complete
# 41f64f9d12ca: Verifying Checksum
# 41f64f9d12ca: Download complete
# 00d1c09f699a: Verifying Checksum
# 00d1c09f699a: Download complete
# efb648489c68: Verifying Checksum
# efb648489c68: Download complete
# 4007a89234b4: Pull complete
# 5dfa26c6b9c9: Pull complete
# 0ba7bf18aa40: Pull complete
# 4c6ec688ebe3: Pull complete
# 574f361512d6: Pull complete
# db4d1e2d7079: Pull complete
# e544ee0f522d: Pull complete
# c655136086be: Pull complete
# 2ec37f44090c: Pull complete
# 5fba3bd4a2c4: Pull complete
# 7e0ea9d0a1ab: Pull complete
# da005f826951: Pull complete
# ac4e1c91b241: Pull complete
# efb648489c68: Pull complete
# e5e2bb35fef1: Pull complete
# 41f64f9d12ca: Pull complete
# 404e390f8ac9: Pull complete
# 00d1c09f699a: Pull complete
# Digest: sha256:a42e3315fb9cd2730a052be10a9492e8f265703745b1e8029604c5c178f93426
# Status: Downloaded newer image for viennaglobal.azurecr.io/azureml/azureml_4539de3ccb169db6707c8cade7afe14c:latest
# viennaglobal.azurecr.io/azureml/azureml_4539de3ccb169db6707c8cade7afe14c:latest
# 2021-05-31T23:57:53Z Check if container 3566d9b7-7f46-43d9-b42f-74c7a53b44f5_DataSidecar already exist exited with 0,
#
#
# Streaming azureml-logs/65_job_prep-tvmps_007a9e0585dac890f4ea395a1d78dd48ecd3c0948cfd67e525d20a46fc846d08_d.txt
# ===============================================================================================================
# [2021-05-31T23:58:11.538709] Entering job preparation.
# [2021-05-31T23:58:12.056412] Starting job preparation.
# [2021-05-31T23:58:12.056471] Extracting the control code.
# [2021-05-31T23:58:12.063918] fetching and extracting the control code on master node.
# [2021-05-31T23:58:12.063947] Starting extract_project.
# [2021-05-31T23:58:12.063985] Starting to extract zip file.
# [2021-05-31T23:58:12.457086] Finished extracting zip file.
# [2021-05-31T23:58:12.576293] Using urllib.request Python 3.0 or later
# [2021-05-31T23:58:12.576371] Start fetching snapshots.
# [2021-05-31T23:58:12.576410] Start fetching snapshot.
# [2021-05-31T23:58:12.576425] Retrieving project from snapshot: 9c60f3db-ef0a-4567-81af-947818d97720
# Starting the daemon thread to refresh tokens in background for process with pid = 45
# [2021-05-31T23:58:12.844864] Finished fetching snapshot.
# [2021-05-31T23:58:12.844895] Start fetching snapshot.
# [2021-05-31T23:58:12.844919] Retrieving project from snapshot: 646a809b-430a-4edd-b373-1f686b1e2b2a
# [2021-05-31T23:58:21.941324] Finished fetching snapshot.
# [2021-05-31T23:58:21.941359] Finished fetching snapshots.
# [2021-05-31T23:58:21.941523] Finished extract_project.
# [2021-05-31T23:58:21.952489] Finished fetching and extracting the control code.
# [2021-05-31T23:58:21.960820] Start run_history_prep.
# [2021-05-31T23:58:22.006625] Job preparation is complete.
# [2021-05-31T23:58:22.006790] Entering Data Context Managers in Sidecar
# [2021-05-31T23:58:22.007488] Running Sidecar prep cmd...
# [2021-05-31T23:58:22.391744] INFO azureml.sidecar.sidecar: Received task: enter_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/aml-revision/azureml/3566d9b7-7f46-43d9-b42f-74c7a53b44f5/mounts/workspaceblobstore/azureml/3566d9b7-7f46-43d9-b42f-74c7a53b44f5
# [2021-05-31T23:58:22.392718] INFO azureml.sidecar.sidecar: Invoking "enter_contexts" task with Context Managers: {"context_managers": ["Dataset:context_managers.Datasets", "DataStoreCopy:context_managers.DataStores"]}
# Enter __enter__ of DatasetContextManager
# SDK version: azureml-core==1.26.0 azureml-dataprep==2.14.2. Session id: 508df3a9-b5aa-4959-9795-2f512d75e649. Run id: 3566d9b7-7f46-43d9-b42f-74c7a53b44f5.
# Processing 'diabetes_batch'.
# Processing dataset FileDataset
# {
#   "source": [
#     "('workspaceblobstore', 'batch-data/')"
#   ],
#   "definition": [
#     "GetDatastoreFiles"
#   ],
#   "registration": {
#     "id": "7f54e636-7c02-418f-b260-0a99185a2bb3",
#     "name": "batch-data",
#     "version": 1,
#     "description": "batch data",
#     "workspace": "Workspace.create(name='aml-revision', subscription_id='ecdf148e-e3eb-433a-9970-91b083980992', resource_group='aml-resources-2')"
#   }
# }
# Mounting diabetes_batch to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/aml-revision/azureml/3566d9b7-7f46-43d9-b42f-74c7a53b44f5/wd/diabetes_batch_7f54e636-7c02-418f-b260-0a99185a2bb3.
# Mounted diabetes_batch to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/aml-revision/azureml/3566d9b7-7f46-43d9-b42f-74c7a53b44f5/wd/diabetes_batch_7f54e636-7c02-418f-b260-0a99185a2bb3 as folder.
# Exit __enter__ of DatasetContextManager
# Set Dataset diabetes_batch's target path to /mnt/batch/tasks/shared/LS_root/jobs/aml-revision/azureml/3566d9b7-7f46-43d9-b42f-74c7a53b44f5/wd/diabetes_batch_7f54e636-7c02-418f-b260-0a99185a2bb3
# Acquired lockfile /tmp/3566d9b7-7f46-43d9-b42f-74c7a53b44f5-datastore.lock to downloading input data references
# [2021-05-31T23:58:32.467870] INFO azureml.sidecar.task.enter_contexts: Entered Context Managers
# [2021-05-31T23:58:32.981864] Ran Sidecar prep cmd.
# [2021-05-31T23:58:32.981953] Running Context Managers in Sidecar complete.
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
# 2021/05/31 23:59:24 Starting App Insight Logger for task:  runTaskLet
# 2021/05/31 23:59:24 Attempt 1 of http call to http://10.0.0.4:16384/sendlogstoartifacts/info
# 2021/05/31 23:59:24 Attempt 1 of http call to http://10.0.0.4:16384/sendlogstoartifacts/status
# [2021-05-31T23:59:24.993494] Entering context manager injector.
# [context_manager_injector.py] Command line Options: Namespace(inject=['ProjectPythonPath:context_managers.ProjectPythonPath', 'Dataset:context_managers.Datasets', 'RunHistory:context_managers.RunHistory', 'TrackUserError:context_managers.TrackUserError'], invocation=['driver/amlbi_main.py', '--client_sdk_version', '1.27.0', '--scoring_module_name', 'batch_diabetes.py', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--output', '/mnt/batch/tasks/shared/LS_root/jobs/aml-revision/azureml/3566d9b7-7f46-43d9-b42f-74c7a53b44f5/mounts/workspaceblobstore/azureml/3566d9b7-7f46-43d9-b42f-74c7a53b44f5/inferences', '--input_fds_0', 'diabetes_batch'])
# Script type = None
# [2021-05-31T23:59:26.126849] Entering Run History Context Manager.
# [2021-05-31T23:59:26.706506] Current directory: /mnt/batch/tasks/shared/LS_root/jobs/aml-revision/azureml/3566d9b7-7f46-43d9-b42f-74c7a53b44f5/mounts/workspaceblobstore/azureml/3566d9b7-7f46-43d9-b42f-74c7a53b44f5
# [2021-05-31T23:59:26.706744] Preparing to call script [driver/amlbi_main.py] with arguments:['--client_sdk_version', '1.27.0', '--scoring_module_name', 'batch_diabetes.py', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--output', '/mnt/batch/tasks/shared/LS_root/jobs/aml-revision/azureml/3566d9b7-7f46-43d9-b42f-74c7a53b44f5/mounts/workspaceblobstore/azureml/3566d9b7-7f46-43d9-b42f-74c7a53b44f5/inferences', '--input_fds_0', 'diabetes_batch']
# [2021-05-31T23:59:26.706852] After variable expansion, calling script [driver/amlbi_main.py] with arguments:['--client_sdk_version', '1.27.0', '--scoring_module_name', 'batch_diabetes.py', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--output', '/mnt/batch/tasks/shared/LS_root/jobs/aml-revision/azureml/3566d9b7-7f46-43d9-b42f-74c7a53b44f5/mounts/workspaceblobstore/azureml/3566d9b7-7f46-43d9-b42f-74c7a53b44f5/inferences', '--input_fds_0', 'diabetes_batch']
#
# 2021/05/31 23:59:29 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 1
# FilteredData: 0.
#
# Streaming azureml-logs/75_job_post-tvmps_007a9e0585dac890f4ea395a1d78dd48ecd3c0948cfd67e525d20a46fc846d08_d.txt
# ===============================================================================================================
# [2021-06-01T00:00:12.737630] Entering job release
# [2021-06-01T00:00:13.982466] Starting job release
# [2021-06-01T00:00:13.983015] Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 271
# [2021-06-01T00:00:13.983618] job release stage : upload_datastore starting...
# [2021-06-01T00:00:13.986561] job release stage : start importing azureml.history._tracking in run_history_release.
# [2021-06-01T00:00:13.986801] job release stage : execute_job_release starting...
# [2021-06-01T00:00:13.987210] job release stage : copy_batchai_cached_logs starting...
# [2021-06-01T00:00:13.987345] job release stage : copy_batchai_cached_logs completed...
# [2021-06-01T00:00:14.054195] Entering context manager injector.
# [2021-06-01T00:00:14.097290] job release stage : upload_datastore completed...
# [2021-06-01T00:00:14.125930] job release stage : send_run_telemetry starting...
# [2021-06-01T00:00:14.127905] job release stage : execute_job_release completed...
# [2021-06-01T00:00:14.325811] get vm size and vm region successfully.
# [2021-06-01T00:00:14.340258] get compute meta data successfully.
# [2021-06-01T00:00:14.485731] post artifact meta request successfully.
# [2021-06-01T00:00:14.509769] upload compute record artifact successfully.
# [2021-06-01T00:00:14.509905] job release stage : send_run_telemetry completed...
# [2021-06-01T00:00:14.510447] Running in AzureML-Sidecar, starting to exit user context managers...
# [2021-06-01T00:00:14.510580] Running Sidecar release cmd...
# [2021-06-01T00:00:14.520437] INFO azureml.sidecar.sidecar: Received task: exit_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/aml-revision/azureml/3566d9b7-7f46-43d9-b42f-74c7a53b44f5/mounts/workspaceblobstore/azureml/3566d9b7-7f46-43d9-b42f-74c7a53b44f5
# Enter __exit__ of DatasetContextManager
# Unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/aml-revision/azureml/3566d9b7-7f46-43d9-b42f-74c7a53b44f5/wd/diabetes_batch_7f54e636-7c02-418f-b260-0a99185a2bb3.
# Finishing unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/aml-revision/azureml/3566d9b7-7f46-43d9-b42f-74c7a53b44f5/wd/diabetes_batch_7f54e636-7c02-418f-b260-0a99185a2bb3.
# Exit __exit__ of DatasetContextManager
# [2021-06-01T00:00:14.629541] Removing absolute paths from host...
# [2021-06-01T00:00:14.636503] INFO azureml.sidecar.task.exit_contexts: Exited Context Managers
# [2021-06-01T00:00:15.534694] Ran Sidecar release cmd.
# [2021-06-01T00:00:15.534785] Job release is complete
# StepRun(batch-score-diabetes) Execution Summary
# ================================================
# StepRun( batch-score-diabetes ) Status: Finished
# {'runId': '3566d9b7-7f46-43d9-b42f-74c7a53b44f5', 'target': 'azCompCluster', 'status': 'Completed', 'startTimeUtc': '2021-05-31T23:57:11.701692Z', 'endTimeUtc': '2021-06-01T00:01:30.709168Z', 'properties': {'ContentSnapshotId': '9c60f3db-ef0a-4567-81af-947818d97720', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': '5afcf187-f321-4537-9601-ce708e93cc52', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': 'c581fa7c', 'azureml.pipelinerunid': '59edae82-2160-4f83-8e4a-bee136d9c605', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json', 'azureml.parallelrunstep': 'true'}, 'inputDatasets': [{'dataset': {'id': '7f54e636-7c02-418f-b260-0a99185a2bb3'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'diabetes_batch', 'mechanism': 'Mount'}}], 'outputDatasets': [], 'runDefinition': {'script': 'driver/amlbi_main.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--client_sdk_version', '1.27.0', '--scoring_module_name', 'batch_diabetes.py', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--output', '$AZUREML_DATAREFERENCE_inferences', '--input_fds_0', 'diabetes_batch'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'azCompCluster', 'dataReferences': {'inferences': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/3566d9b7-7f46-43d9-b42f-74c7a53b44f5/inferences', 'pathOnCompute': 'diabetes/results', 'overwrite': False}}, 'data': {'diabetes_batch': {'dataLocation': {'dataset': {'id': '7f54e636-7c02-418f-b260-0a99185a2bb3', 'name': None, 'version': '1'}, 'dataPath': None, 'uri': None}, 'mechanism': 'Mount', 'environmentVariableName': 'diabetes_batch', 'pathOnCompute': None, 'overwrite': False}}, 'outputData': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 2, 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'batch_environment', 'version': 'Autosave_2021-05-31T23:44:56Z_d09ff955', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['azureml-defaults~=1.27.0', 'azureml-core~=1.27.0', 'azureml-dataprep[fuse]']}, 'scikit-learn', 'pip'], 'name': 'azureml_aa77a7252d8f04306986f9fa8a3997ad'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210301.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'dockerContext': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': None, 'imageVersion': None, 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None, 'virtualClusterArmId': None, 'tensorboardLogDirectory': None, 'sshPublicKey': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'pyTorch': {'communicationBackend': 'nccl', 'processCount': None}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'contain ...
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '59edae82-2160-4f83-8e4a-bee136d9c605', 'status': 'Completed', 'startTimeUtc': '2021-05-31T23:43:45.012602Z', 'endTimeUtc': '2021-06-01T00:01:33.120346Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://amlrevision3565263528.blob.core.windows.net/azureml/ExperimentRun/dcid.59edae82-2160-4f83-8e4a-bee136d9c605/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=R%2Bo42HYeGSSVk2QtheYy%2B%2BfNp3OuOB%2F9hiDzJyJw%2BMY%3D&st=2021-05-31T23%3A51%3A34Z&se=2021-06-01T08%3A01%3A34Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://amlrevision3565263528.blob.core.windows.net/azureml/ExperimentRun/dcid.59edae82-2160-4f83-8e4a-bee136d9c605/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=bzCpPWcXbDAdqRJ6Q3aap%2BSP5%2Fas743yUWRrVwuZOoE%3D&st=2021-05-31T23%3A51%3A34Z&se=2021-06-01T08%3A01%3A34Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://amlrevision3565263528.blob.core.windows.net/azureml/ExperimentRun/dcid.59edae82-2160-4f83-8e4a-bee136d9c605/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=QmKPoN4SNi3udKj5yyirIP%2BnGx1iej7uzs6PVnQNA1U%3D&st=2021-05-31T23%3A51%3A34Z&se=2021-06-01T08%3A01%3A34Z&sp=r'}, 'submittedBy': 'Harsh Vardhan'}
# 'Finished'

# %% [markdown]
# When the pipeline has finished running, the resulting predictions will have been saved in the outputs of the experiment associated with the first (and only) step in the pipeline. You can retrieve it as follows:

# %%
import pandas as pd
import shutil

# Remove the local results folder if left over from a previous run
shutil.rmtree('diabetes-results', ignore_errors=True)

# Get the run for the first step and download its output
prediction_run = next(pipeline_run.get_children())
prediction_output = prediction_run.get_output_data('inferences')
prediction_output.download(local_path='diabetes-results')

# Traverse the folder hierarchy and find the results file
for root, dirs, files in os.walk('diabetes-results'):
    for file in files:
        if file.endswith('parallel_run_step.txt'):
            result_file = os.path.join(root,file)

# cleanup output format
df = pd.read_csv(result_file, delimiter=":", header=None)
df.columns = ["File", "Prediction"]

# Display the first 20 results
df.head(20)
# Out:
#       File  Prediction
# 0   31.csv           0
# 1   32.csv           0
# 2   33.csv           0
# 3   34.csv           1
# 4   35.csv           0
# 5   22.csv           0
# 6   23.csv           1
# 7   24.csv           0
# 8   25.csv           0
# 9   26.csv           0
# 10  45.csv           0
# 11  46.csv           0
# 12  47.csv           1
# 13  48.csv           0
# 14  49.csv           0
# 15  68.csv           0
# 16  69.csv           1
# 17   7.csv           0
# 18  70.csv           0
# 19  71.csv           0

# %% [markdown]
# ## Publish the Pipeline and use its REST Interface
#
# Now that you have a working pipeline for batch inferencing, you can publish it and use a REST endpoint to run it from an application.

# %%
published_pipeline = pipeline_run.publish_pipeline(
    name='diabetes-batch-pipeline', description='Batch scoring of diabetes data', version='1.0')

published_pipeline
# Out:
# Pipeline(Name: diabetes-batch-pipeline,
# Id: b5075b75-1812-4dd9-92bc-cedf3f0eb907,
# Status: Active,
# Endpoint: https://westus2.api.azureml.ms/pipelines/v1.0/subscriptions/ecdf148e-e3eb-433a-9970-91b083980992/resourceGroups/aml-resources-2/providers/Microsoft.MachineLearningServices/workspaces/aml-revision/PipelineRuns/PipelineSubmit/b5075b75-1812-4dd9-92bc-cedf3f0eb907)

# %% [markdown]
# Note that the published pipeline has an endpoint, which you can see in the Azure portal. You can also find it as a property of the published pipeline object:

# %%
rest_endpoint = published_pipeline.endpoint
print(rest_endpoint)
# Out:
# https://westus2.api.azureml.ms/pipelines/v1.0/subscriptions/ecdf148e-e3eb-433a-9970-91b083980992/resourceGroups/aml-resources-2/providers/Microsoft.MachineLearningServices/workspaces/aml-revision/PipelineRuns/PipelineSubmit/b5075b75-1812-4dd9-92bc-cedf3f0eb907

# %% [markdown]
# To use the endpoint, client applications need to make a REST call over HTTP. This request must be authenticated, so an authorization header is required. To test this out, we'll use the authorization header from your current connection to your Azure workspace, which you can get using the following code:
#
# > **Note**: A real application would require a service principal with which to be authenticated.

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()
print('Authentication header ready.')
# Out:
# Authentication header ready.

# %% [markdown]
# Now we're ready to call the REST interface. The pipeline runs asynchronously, so we'll get an identifier back, which we can use to track the pipeline experiment as it runs:

# %%
import requests

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": "mslearn-diabetes-batch"})
run_id = response.json()["Id"]
run_id
# Out:
# '7b605996-04a5-4ec5-b14c-558ef7a149a2'

# %% [markdown]
# Since we have the run ID, we can use the **RunDetails** widget to view the experiment as it runs:

# %%
from azureml.pipeline.core.run import PipelineRun
from azureml.widgets import RunDetails

published_pipeline_run = PipelineRun(ws.experiments['mslearn-diabetes-batch'], run_id)

# Block until the run completes
published_pipeline_run.wait_for_completion(show_output=True)
# Out:
# PipelineRunId: 7b605996-04a5-4ec5-b14c-558ef7a149a2
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/7b605996-04a5-4ec5-b14c-558ef7a149a2?wsid=/subscriptions/ecdf148e-e3eb-433a-9970-91b083980992/resourcegroups/aml-resources-2/workspaces/aml-revision&tid=798d0da9-368e-472e-83b1-e8d76c71d339
# PipelineRun Status: NotStarted
# PipelineRun Status: Running
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '7b605996-04a5-4ec5-b14c-558ef7a149a2', 'status': 'Completed', 'startTimeUtc': '2021-06-01T00:01:40.915676Z', 'endTimeUtc': '2021-06-01T00:01:43.057857Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'Unavailable', 'runType': 'HTTP', 'azureml.parameters': '{}', 'azureml.pipelineid': 'b5075b75-1812-4dd9-92bc-cedf3f0eb907'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://amlrevision3565263528.blob.core.windows.net/azureml/ExperimentRun/dcid.7b605996-04a5-4ec5-b14c-558ef7a149a2/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=NRtIloVXq12Z1c1INlQ51FW3jYQ38DAkFAD4hnGI5rQ%3D&st=2021-05-31T23%3A51%3A43Z&se=2021-06-01T08%3A01%3A43Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://amlrevision3565263528.blob.core.windows.net/azureml/ExperimentRun/dcid.7b605996-04a5-4ec5-b14c-558ef7a149a2/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=gh6js286IqtxS%2FqCNBYDPCLBZbtSxwOfaCW0rxLpC2Q%3D&st=2021-05-31T23%3A51%3A43Z&se=2021-06-01T08%3A01%3A43Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://amlrevision3565263528.blob.core.windows.net/azureml/ExperimentRun/dcid.7b605996-04a5-4ec5-b14c-558ef7a149a2/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=kjK84i2RaKNNxkHlRT7siDviZF%2FboBQkpIjgayCW7A4%3D&st=2021-05-31T23%3A51%3A43Z&se=2021-06-01T08%3A01%3A43Z&sp=r'}, 'submittedBy': 'Harsh Vardhan'}
# 'Finished'

# %% [markdown]
# Wait for the pipeline run to complete, and then run the following cell to see the results.
#
# As before, the results are in the output of the first pipeline step:

# %%
import pandas as pd
import shutil

# Remove the local results folder if left over from a previous run
shutil.rmtree('diabetes-results', ignore_errors=True)

# Get the run for the first step and download its output
prediction_run = next(pipeline_run.get_children())
prediction_output = prediction_run.get_output_data('inferences')
prediction_output.download(local_path='diabetes-results')

# Traverse the folder hierarchy and find the results file
for root, dirs, files in os.walk('diabetes-results'):
    for file in files:
        if file.endswith('parallel_run_step.txt'):
            result_file = os.path.join(root,file)

# cleanup output format
df = pd.read_csv(result_file, delimiter=":", header=None)
df.columns = ["File", "Prediction"]

# Display the first 20 results
df.head(20)
# Out:
#       File  Prediction
# 0   31.csv           0
# 1   32.csv           0
# 2   33.csv           0
# 3   34.csv           1
# 4   35.csv           0
# 5   22.csv           0
# 6   23.csv           1
# 7   24.csv           0
# 8   25.csv           0
# 9   26.csv           0
# 10  45.csv           0
# 11  46.csv           0
# 12  47.csv           1
# 13  48.csv           0
# 14  49.csv           0
# 15  68.csv           0
# 16  69.csv           1
# 17   7.csv           0
# 18  70.csv           0
# 19  71.csv           0

# %% [markdown]
# Now you have a pipeline that can be used to batch process daily patient data.
#
# **More Information**: For more details about using pipelines for batch inferencing, see the [How to Run Batch Predictions](https://docs.microsoft.com/azure/machine-learning/how-to-run-batch-predictions) in the Azure Machine Learning documentation.
