# %% [markdown]
# # Create a Pipeline
#
# You can perform the various steps required to ingest data, train a model, and register the model individually by using the Azure ML SDK to run script-based experiments. However, in an enterprise environment it is common to encapsulate the sequence of discrete steps required to build a machine learning solution into a *pipeline* that can be run on one or more compute targets, either on-demand by a user, from an automated build process, or on a schedule.
#
# In this notebook, you'll bring together all of these elements to create a simple pipeline that pre-processes data and then trains and registers a model.

# %% [markdown]
# ## Connect to your workspace
#
# To get started, connect to your workspace.
#
# > **Note**: If you haven't already established an authenticated session with your Azure subscription, you'll be prompted to authenticate by clicking a link, entering an authentication code, and signing into Azure.

# %%
import azureml.core
from azureml.core import Workspace

# Load the workspace from the saved config file
ws = Workspace.from_config()
print('Ready to use Azure ML {} to work with {}'.format(azureml.core.VERSION, ws.name))
# Out:
# Ready to use Azure ML 1.27.0 to work with aml-revision

# %% [markdown]
# ## Prepare data
#
# In your pipeline, you'll use a dataset containing details of diabetes patients. Run the cell below to create this dataset (if you created it in previously, the code will find the existing version)

# %%
from azureml.core import Dataset

default_ds = ws.get_default_datastore()

if 'diabetes dataset' not in ws.datasets:
    default_ds.upload_files(files=['./data/diabetes.csv', './data/diabetes2.csv'], # Upload the diabetes csv files in /data
                        target_path='diabetes-data/', # Put it in a folder path in the datastore
                        overwrite=True, # Replace existing files of the same name
                        show_progress=True)

    #Create a tabular dataset from the path on the datastore (this may take a short while)
    tab_data_set = Dataset.Tabular.from_delimited_files(path=(default_ds, 'diabetes-data/*.csv'))

    # Register the tabular dataset
    try:
        tab_data_set = tab_data_set.register(workspace=ws, 
                                name='diabetes dataset',
                                description='diabetes data',
                                tags = {'format':'CSV'},
                                create_new_version=True)
        print('Dataset registered.')
    except Exception as ex:
        print(ex)
else:
    print('Dataset already registered.')
# Out:
# Dataset already registered.

# %% [markdown]
# ## Create scripts for pipeline steps
#
# Pipelines consist of one or more *steps*, which can be Python scripts, or specialized steps like a data transfer step that copies data from one location to another. Each step can run in its own compute context. In this exercise, you'll build a simple pipeline that contains two Python script steps: one to pre-process some training data, and another to use the pre-processed data to train and register a model.
#
# First, let's create a folder for the script files we'll use in the pipeline steps.

# %%
import os
# Create a folder for the pipeline step files
experiment_folder = 'diabetes_pipeline'
os.makedirs(experiment_folder, exist_ok=True)

print(experiment_folder)
# Out:
# diabetes_pipeline

# %% [markdown]
# Now let's create the first script, which will read data from the diabetes dataset and apply some simple pre-processing to remove any rows with missing data and normalize the numeric features so they're on a similar scale.
#
# The script includes a argument named **--prepped-data**, which references the folder where the resulting data should be saved.

# %%
# %%writefile $experiment_folder/prep_diabetes.py
# Import libraries
import os
import argparse
import pandas as pd
from azureml.core import Run
from sklearn.preprocessing import MinMaxScaler

# Get parameters
parser = argparse.ArgumentParser()
parser.add_argument("--input-data", type=str, dest='raw_dataset_id', help='raw dataset')
parser.add_argument('--prepped-data', type=str, dest='prepped_data', default='prepped_data', help='Folder for results')
args = parser.parse_args()
save_folder = args.prepped_data

# Get the experiment run context
run = Run.get_context()

# load the data (passed as an input dataset)
print("Loading Data...")
diabetes = run.input_datasets['raw_data'].to_pandas_dataframe()

# Log raw row count
row_count = (len(diabetes))
run.log('raw_rows', row_count)

# remove nulls
diabetes = diabetes.dropna()

# Normalize the numeric columns
scaler = MinMaxScaler()
num_cols = ['Pregnancies','PlasmaGlucose','DiastolicBloodPressure','TricepsThickness','SerumInsulin','BMI','DiabetesPedigree']
diabetes[num_cols] = scaler.fit_transform(diabetes[num_cols])

# Log processed rows
row_count = (len(diabetes))
run.log('processed_rows', row_count)

# Save the prepped data
print("Saving Data...")
os.makedirs(save_folder, exist_ok=True)
save_path = os.path.join(save_folder,'data.csv')
diabetes.to_csv(save_path, index=False, header=True)

# End the run
run.complete()
# Out:
# Overwriting diabetes_pipeline/prep_diabetes.py

# %% [markdown]
# Now you can create the script for the second step, which will train a model. The script includes a argument named **--training-folder**, which references the folder where the prepared data was saved by the previous step.

# %%
# %%writefile $experiment_folder/train_diabetes.py
# Import libraries
from azureml.core import Run, Model
import argparse
import pandas as pd
import numpy as np
import joblib
import os
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt

# Get parameters
parser = argparse.ArgumentParser()
parser.add_argument("--training-folder", type=str, dest='training_folder', help='training data folder')
args = parser.parse_args()
training_folder = args.training_folder

# Get the experiment run context
run = Run.get_context()

# load the prepared data file in the training folder
print("Loading Data...")
file_path = os.path.join(training_folder,'data.csv')
diabetes = pd.read_csv(file_path)

# Separate features and labels
X, y = diabetes[['Pregnancies','PlasmaGlucose','DiastolicBloodPressure','TricepsThickness','SerumInsulin','BMI','DiabetesPedigree','Age']].values, diabetes['Diabetic'].values

# Split data into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=0)

# Train adecision tree model
print('Training a decision tree model...')
model = DecisionTreeClassifier().fit(X_train, y_train)

# calculate accuracy
y_hat = model.predict(X_test)
acc = np.average(y_hat == y_test)
print('Accuracy:', acc)
run.log('Accuracy', np.float(acc))

# calculate AUC
y_scores = model.predict_proba(X_test)
auc = roc_auc_score(y_test,y_scores[:,1])
print('AUC: ' + str(auc))
run.log('AUC', np.float(auc))

# plot ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_scores[:,1])
fig = plt.figure(figsize=(6, 4))
# Plot the diagonal 50% line
plt.plot([0, 1], [0, 1], 'k--')
# Plot the FPR and TPR achieved by our model
plt.plot(fpr, tpr)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
run.log_image(name = "ROC", plot = fig)
plt.show()

# Save the trained model in the outputs folder
print("Saving model...")
os.makedirs('outputs', exist_ok=True)
model_file = os.path.join('outputs', 'diabetes_model.pkl')
joblib.dump(value=model, filename=model_file)

# Register the model
print('Registering model...')
Model.register(workspace=run.experiment.workspace,
               model_path = model_file,
               model_name = 'diabetes_model',
               tags={'Training context':'Pipeline'},
               properties={'AUC': np.float(auc), 'Accuracy': np.float(acc)})


run.complete()
# Out:
# Overwriting diabetes_pipeline/train_diabetes.py

# %% [markdown]
# ## Prepare a compute environment for the pipeline steps
#
# In this exercise, you'll use the same compute for both steps, but it's important to realize that each step is run independently; so you could specify different compute contexts for each step if appropriate.
#
# First, get the compute target you created in a previous lab (if it doesn't exist, it will be created).
#
# > **Important**: Change *your-compute-cluster* to the name of your compute cluster in the code below before running it! Cluster names must be globally unique names between 2 to 16 characters in length. Valid characters are letters, digits, and the - character.

# %%
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

cluster_name = "azCompCluster"

try:
    # Check for existing compute target
    pipeline_cluster = ComputeTarget(workspace=ws, name=cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    # If it doesn't already exist, create it
    try:
        compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_DS11_V2', max_nodes=2)
        pipeline_cluster = ComputeTarget.create(ws, cluster_name, compute_config)
        pipeline_cluster.wait_for_completion(show_output=True)
    except Exception as ex:
        print(ex)
# Out:
# Found existing cluster, use it.

# %% [markdown]
# The compute will require a Python environment with the necessary package dependencies installed, so you'll need to create a run configuration.

# %%
from azureml.core import Environment
from azureml.core.conda_dependencies import CondaDependencies
from azureml.core.runconfig import RunConfiguration

# Create a Python environment for the experiment
diabetes_env = Environment("diabetes-pipeline-env")

# Create a set of package dependencies
diabetes_packages = CondaDependencies.create(conda_packages=['scikit-learn','ipykernel','matplotlib','pandas','pip'],
                                             pip_packages=['azureml-defaults','azureml-dataprep[pandas]','pyarrow'])

# Add the dependencies to the environment
diabetes_env.python.conda_dependencies = diabetes_packages

# Register the environment 
diabetes_env.register(workspace=ws)
registered_env = Environment.get(ws, 'diabetes-pipeline-env')

# Create a new runconfig object for the pipeline
pipeline_run_config = RunConfiguration()

# Use the compute you created above. 
pipeline_run_config.target = pipeline_cluster

# Assign the environment to the run configuration
pipeline_run_config.environment = registered_env

print ("Run configuration created.")
# Out:
# Run configuration created.

# %% [markdown]
# ## Create and run a pipeline
#
# Now you're ready to create and run a pipeline.
#
# First you need to define the steps for the pipeline, and any data references that need to be passed between them. In this case, the first step must write the prepared data to a folder that can be read from by the second step. Since the steps will be run on remote compute (and in fact, could each be run on different compute), the folder path must be passed as a data reference to a location in a datastore within the workspace. The **PipelineData** object is a special kind of data reference that is used for interim storage locations that can be passed between pipeline steps, so you'll create one and use at as the output for the first step and the input for the second step. Note that you also need to pass it as a script argument so our code can access the datastore location referenced by the data reference.

# %%
from azureml.pipeline.core import PipelineData
from azureml.pipeline.steps import PythonScriptStep

# Get the training dataset
diabetes_ds = ws.datasets.get("diabetes dataset")

# Create a PipelineData (temporary Data Reference) for the model folder
prepped_data_folder = PipelineData("prepped_data_folder", datastore=ws.get_default_datastore())

# Step 1, Run the data prep script
prep_step = PythonScriptStep(name = "Prepare Data",
                                source_directory = experiment_folder,
                                script_name = "prep_diabetes.py",
                                arguments = ['--input-data', diabetes_ds.as_named_input('raw_data'),
                                             '--prepped-data', prepped_data_folder],
                                outputs=[prepped_data_folder],
                                compute_target = pipeline_cluster,
                                runconfig = pipeline_run_config,
                                allow_reuse = True)

# Step 2, run the training script
train_step = PythonScriptStep(name = "Train and Register Model",
                                source_directory = experiment_folder,
                                script_name = "train_diabetes.py",
                                arguments = ['--training-folder', prepped_data_folder],
                                inputs=[prepped_data_folder],
                                compute_target = pipeline_cluster,
                                runconfig = pipeline_run_config,
                                allow_reuse = True)

print("Pipeline steps defined")
# Out:
# Pipeline steps defined

# %% [markdown]
# OK, you're ready build the pipeline from the steps you've defined and run it as an experiment.

# %%
from azureml.core import Experiment
from azureml.pipeline.core import Pipeline
from azureml.widgets import RunDetails

# Construct the pipeline
pipeline_steps = [prep_step, train_step]
pipeline = Pipeline(workspace=ws, steps=pipeline_steps)
print("Pipeline is built.")

# Create an experiment and run the pipeline
experiment = Experiment(workspace=ws, name = 'mslearn-diabetes-pipeline')
pipeline_run = experiment.submit(pipeline, regenerate_outputs=True)
print("Pipeline submitted for execution.")
RunDetails(pipeline_run).show()
pipeline_run.wait_for_completion(show_output=True)
# Out:
# Pipeline is built.
# Created step Prepare Data [a92191cc][90ebaa2c-625a-44f2-b79f-612fb6b9dd7d], (This step will run and generate new outputs)
# Created step Train and Register Model [f1811279][be431421-53be-439b-8de2-78eb09f875e1], (This step will run and generate new outputs)
# Submitted PipelineRun 8fda1c0c-35c0-400b-bba6-39f268c22c6a
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/8fda1c0c-35c0-400b-bba6-39f268c22c6a?wsid=/subscriptions/ecdf148e-e3eb-433a-9970-91b083980992/resourcegroups/aml-resources-2/workspaces/aml-revision&tid=798d0da9-368e-472e-83b1-e8d76c71d339
# Pipeline submitted for execution.
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …
# PipelineRunId: 8fda1c0c-35c0-400b-bba6-39f268c22c6a
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/8fda1c0c-35c0-400b-bba6-39f268c22c6a?wsid=/subscriptions/ecdf148e-e3eb-433a-9970-91b083980992/resourcegroups/aml-resources-2/workspaces/aml-revision&tid=798d0da9-368e-472e-83b1-e8d76c71d339
# PipelineRun Status: Running
#
#
# StepRunId: 161ac072-e7b6-4525-9af1-36d3979aee4a
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/161ac072-e7b6-4525-9af1-36d3979aee4a?wsid=/subscriptions/ecdf148e-e3eb-433a-9970-91b083980992/resourcegroups/aml-resources-2/workspaces/aml-revision&tid=798d0da9-368e-472e-83b1-e8d76c71d339
# StepRun( Prepare Data ) Status: Running
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
# 2021/05/31 21:30:59 Downloading source code...
# 2021/05/31 21:31:01 Finished downloading source code
# 2021/05/31 21:31:01 Creating Docker network: acb_default_network, driver: 'bridge'
# 2021/05/31 21:31:02 Successfully set up Docker network: acb_default_network
# 2021/05/31 21:31:02 Setting up Docker configuration...
# 2021/05/31 21:31:03 Successfully set up Docker configuration
# 2021/05/31 21:31:03 Logging in to registry: a17537c43d7f425dabe668516b2725e3.azurecr.io
# 2021/05/31 21:31:04 Successfully logged into a17537c43d7f425dabe668516b2725e3.azurecr.io
# 2021/05/31 21:31:04 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/05/31 21:31:04 Scanning for dependencies...
# 2021/05/31 21:31:05 Successfully scanned dependencies
# 2021/05/31 21:31:05 Launching container with name: acb_step_0
# Sending build context to Docker daemon  66.56kB
#
# Step 1/18 : FROM mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210301.v1@sha256:000d6c43f606ceaa67983790ca95c70fd741c364d8c2e3217a11d775b99741df
# mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210301.v1@sha256:000d6c43f606ceaa67983790ca95c70fd741c364d8c2e3217a11d775b99741df: Pulling from azureml/intelmpi2018.3-ubuntu16.04
# Digest: sha256:000d6c43f606ceaa67983790ca95c70fd741c364d8c2e3217a11d775b99741df
# Status: Downloaded newer image for mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210301.v1@sha256:000d6c43f606ceaa67983790ca95c70fd741c364d8c2e3217a11d775b99741df
#  ---> c942df5ba5d0
# Step 2/18 : USER root
#  ---> Running in 9fe5112e3a9f
# Removing intermediate container 9fe5112e3a9f
#  ---> 0c45500c1f87
# Step 3/18 : RUN mkdir -p $HOME/.cache
#  ---> Running in 52c274d3a00d
# Removing intermediate container 52c274d3a00d
#  ---> 18cce8c3661a
# Step 4/18 : WORKDIR /
#  ---> Running in 0b8d23a80037
# Removing intermediate container 0b8d23a80037
#  ---> e6bc52ed5e6d
# Step 5/18 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> 3c2231b18200
# Step 6/18 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in 4be0fcb02d55
# Removing intermediate container 4be0fcb02d55
#  ---> bf93113db0c1
# Step 7/18 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> d7644cece6a3
# Step 8/18 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_28b0d742a4cb5c02a5befb218632cd1a -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in da0feec03dbf
# Collecting package metadata (repodata.json): ...working...
# done
# Solving environment: ...working...
# done
#
# Downloading and Extracting Packages
#
# ipython-7.16.1       | 1.1 MB    |            |   0%
# ipython-7.16.1       | 1.1 MB    | #2         |  13%
# ipython-7.16.1       | 1.1 MB    | ########## | 100%
# ipython-7.16.1       | 1.1 MB    | ########## | 100%
#
# openssl-1.0.2u       | 3.1 MB    |            |   0%
# openssl-1.0.2u       | 3.1 MB    | ########## | 100%
# openssl-1.0.2u       | 3.1 MB    | ########## | 100%
#
# zeromq-4.3.3         | 678 KB    |            |   0%
# zeromq-4.3.3         | 678 KB    | ########## | 100%
# zeromq-4.3.3         | 678 KB    | ########## | 100%
#
# traitlets-4.3.3      | 137 KB    |            |   0%
# traitlets-4.3.3      | 137 KB    | ########## | 100%
#
# mkl_random-1.1.0     | 369 KB    |            |   0%
# mkl_random-1.1.0     | 369 KB    | ########## | 100%
#
# sip-4.19.24          | 297 KB    |            |   0%
# sip-4.19.24          | 297 KB    | ########## | 100%
#
# parso-0.7.0          | 71 KB     |            |   0%
# parso-0.7.0          | 71 KB     | ########## | 100%
#
# libxml2-2.9.10       | 1.3 MB    |            |   0%
# libxml2-2.9.10       | 1.3 MB    | ########## | 100%
# libxml2-2.9.10       | 1.3 MB    | ########## | 100%
#
# certifi-2020.6.20    | 160 KB    |            |   0%
# certifi-2020.6.20    | 160 KB    | ########## | 100%
#
# joblib-0.17.0        | 205 KB    |            |   0%
# joblib-0.17.0        | 205 KB    | ########## | 100%
#
# jupyter_client-6.1.7 | 76 KB     |            |   0%
# jupyter_client-6.1.7 | 76 KB     | ########## | 100%
#
# zlib-1.2.11          | 120 KB    |            |   0%
# zlib-1.2.11          | 120 KB    | ########## | 100%
#
# pyzmq-19.0.2         | 479 KB    |            |   0%
# pyzmq-19.0.2         | 479 KB    | ########## | 100%
# pyzmq-19.0.2         | 479 KB    | ########## | 100%
#
# tk-8.6.10            | 3.2 MB    |            |   0%
# tk-8.6.10            | 3.2 MB    | ########## | 100%
# tk-8.6.10            | 3.2 MB    | ########## | 100%
#
# pytz-2020.1          | 239 KB    |            |   0%
# pytz-2020.1          | 239 KB    | ########## | 100%
# pytz-2020.1          | 239 KB    | ########## | 100%
#
# ncurses-6.0          | 907 KB    |            |   0%
# ncurses-6.0          | 907 KB    | ########## | 100%
# ncurses-6.0          | 907 KB    | ########## | 100%
#
# pyqt-5.9.2           | 5.6 MB    |            |   0%
# pyqt-5.9.2           | 5.6 MB    | ########## | 100%
# pyqt-5.9.2           | 5.6 MB    | ########## | 100%
#
# libgfortran-ng-7.3.0 | 1.3 MB    |            |   0%
# libgfortran-ng-7.3.0 | 1.3 MB    | ########## | 100%
# libgfortran-ng-7.3.0 | 1.3 MB    | ########## | 100%
#
# pygments-2.7.1       | 704 KB    |            |   0%
# pygments-2.7.1       | 704 KB    | ########## | 100%
# pygments-2.7.1       | 704 KB    | ########## | 100%
#
# wcwidth-0.2.5        | 37 KB     |            |   0%
# wcwidth-0.2.5        | 37 KB     | ########## | 100%
#
# freetype-2.10.4      | 901 KB    |            |   0%
# freetype-2.10.4      | 901 KB    | ########## | 100%
# freetype-2.10.4      | 901 KB    | ########## | 100%
#
# pyparsing-2.4.7      | 64 KB     |            |   0%
# pyparsing-2.4.7      | 64 KB     | ########## | 100%
#
# decorator-4.4.2      | 14 KB     |            |   0%
# decorator-4.4.2      | 14 KB     | ########## | 100%
#
# libuuid-1.0.3        | 16 KB     |            |   0%
# libuuid-1.0.3        | 16 KB     | ########## | 100%
#
# tornado-6.0.4        | 650 KB    |            |   0%
# tornado-6.0.4        | 650 KB    | ########## | 100%
# tornado-6.0.4        | 650 KB    | ########## | 100%
#
# libtiff-4.1.0        | 607 KB    |            |   0%
# libtiff-4.1.0        | 607 KB    | ########## | 100%
# libtiff-4.1.0        | 607 KB    | ########## | 100%
#
# pandas-1.1.3         | 10.5 MB   |            |   0%
# pandas-1.1.3         | 10.5 MB   | #######2   |  73%
# pandas-1.1.3         | 10.5 MB   | ########## | 100%
# pandas-1.1.3         | 10.5 MB   | ########## | 100%
#
# matplotlib-3.3.1     | 24 KB     |            |   0%
# matplotlib-3.3.1     | 24 KB     | ########## | 100%
#
# gstreamer-1.14.0     | 3.8 MB    |            |   0%
# gstreamer-1.14.0     | 3.8 MB    | ########## | 100%
# gstreamer-1.14.0     | 3.8 MB    | ########## | 100%
#
# fontconfig-2.13.0    | 291 KB    |            |   0%
# fontconfig-2.13.0    | 291 KB    | ########## | 100%
#
# python-dateutil-2.8. | 224 KB    |            |   0%
# python-dateutil-2.8. | 224 KB    | ########## | 100%
#
# jpeg-9b              | 247 KB    |            |   0%
# jpeg-9b              | 247 KB    | ########## | 100%
#
# pexpect-4.8.0        | 84 KB     |            |   0%
# pexpect-4.8.0        | 84 KB     | ########## | 100%
#
# expat-2.2.10         | 192 KB    |            |   0%
# expat-2.2.10         | 192 KB    | ########## | 100%
#
# scipy-1.5.2          | 18.5 MB   |            |   0%
# scipy-1.5.2          | 18.5 MB   | ####       |  41%
# scipy-1.5.2          | 18.5 MB   | ########## | 100%
# scipy-1.5.2          | 18.5 MB   | ########## | 100%
#
# libgcc-ng-9.1.0      | 8.1 MB    |            |   0%
# libgcc-ng-9.1.0      | 8.1 MB    | ####3      |  43%
# libgcc-ng-9.1.0      | 8.1 MB    | ########## | 100%
# libgcc-ng-9.1.0      | 8.1 MB    | ########## | 100%
#
# jedi-0.17.2          | 952 KB    |            |   0%
# jedi-0.17.2          | 952 KB    | 1          |   2%
# jedi-0.17.2          | 952 KB    | ##6        |  27%
# jedi-0.17.2          | 952 KB    | #########  |  91%
# jedi-0.17.2          | 952 KB    | ########## | 100%
# pip-20.2.4           | 2.0 MB    |            |   0%
# pip-20.2.4           | 2.0 MB    | ########## | 100%
# pip-20.2.4           | 2.0 MB    | ########## | 100%
#
# prompt-toolkit-3.0.8 | 244 KB    |            |   0%
# prompt-toolkit-3.0.8 | 244 KB    | ########## | 100%
# prompt-toolkit-3.0.8 | 244 KB    | ########## | 100%
#
# lcms2-2.11           | 419 KB    |            |   0%
# lcms2-2.11           | 419 KB    | ########## | 100%
# lcms2-2.11           | 419 KB    | ########## | 100%
#
# dbus-1.13.18         | 586 KB    |            |   0%
# dbus-1.13.18         | 586 KB    | ########## | 100%
# dbus-1.13.18         | 586 KB    | ########## | 100%
#
# icu-58.2             | 22.7 MB   |            |   0%
# icu-58.2             | 22.7 MB   | ##6        |  27%
# icu-58.2             | 22.7 MB   | ######9    |  69%
# icu-58.2             | 22.7 MB   | ########## | 100%
# icu-58.2             | 22.7 MB   | ########## | 100%
#
# ipykernel-5.3.4      | 176 KB    |            |   0%
# ipykernel-5.3.4      | 176 KB    | 9          |   9%
# ipykernel-5.3.4      | 176 KB    | ########## | 100%
#
# backcall-0.2.0       | 14 KB     |            |   0%
# backcall-0.2.0       | 14 KB     | ########## | 100%
#
# numpy-base-1.19.1    | 5.2 MB    |            |   0%
# numpy-base-1.19.1    | 5.2 MB    | ########## | 100%
# numpy-base-1.19.1    | 5.2 MB    | ########## | 100%
#
# numpy-1.19.1         | 20 KB     |            |   0%
# numpy-1.19.1         | 20 KB     | ########## | 100%
#
# ipython_genutils-0.2 | 39 KB     |            |   0%
# ipython_genutils-0.2 | 39 KB     | ########## | 100%
#
# scikit-learn-0.23.2  | 6.9 MB    |            |   0%
# scikit-learn-0.23.2  | 6.9 MB    | #######    |  71%
# scikit-learn-0.23.2  | 6.9 MB    | ########## | 100%
# scikit-learn-0.23.2  | 6.9 MB    | ########## | 100%
#
# libxcb-1.14          | 610 KB    |            |   0%
# libxcb-1.14          | 610 KB    | ########## | 100%
# libxcb-1.14          | 610 KB    | ########## | 100%
#
# pickleshare-0.7.5    | 13 KB     |            |   0%
# pickleshare-0.7.5    | 13 KB     | ########## | 100%
#
# blas-1.0             | 6 KB      |            |   0%
# blas-1.0             | 6 KB      | ########## | 100%
#
# libsodium-1.0.18     | 387 KB    |            |   0%
# libsodium-1.0.18     | 387 KB    | ########## | 100%
# libsodium-1.0.18     | 387 KB    | ########## | 100%
#
# setuptools-50.3.0    | 891 KB    |            |   0%
# setuptools-50.3.0    | 891 KB    | ########## | 100%
# setuptools-50.3.0    | 891 KB    | ########## | 100%
#
# lz4-c-1.9.2          | 203 KB    |            |   0%
# lz4-c-1.9.2          | 203 KB    | ########## | 100%
#
# gst-plugins-base-1.1 | 6.3 MB    |            |   0%
# gst-plugins-base-1.1 | 6.3 MB    | ########## | 100%
# gst-plugins-base-1.1 | 6.3 MB    | ########## | 100%
#
# readline-7.0         | 387 KB    |            |   0%
# readline-7.0         | 387 KB    | ########## | 100%
# readline-7.0         | 387 KB    | ########## | 100%
#
# zstd-1.4.4           | 1006 KB   |            |   0%
# zstd-1.4.4           | 1006 KB   | ########## | 100%
# zstd-1.4.4           | 1006 KB   | ########## | 100%
#
# python-3.6.2         | 27.0 MB   |            |   0%
# python-3.6.2         | 27.0 MB   | ##5        |  26%
# python-3.6.2         | 27.0 MB   | ######3    |  64%
# python-3.6.2         | 27.0 MB   | ########## | 100%
# python-3.6.2         | 27.0 MB   | ########## | 100%
#
# mkl-service-2.3.0    | 208 KB    |            |   0%
# mkl-service-2.3.0    | 208 KB    | ########## | 100%
#
# glib-2.56.2          | 5.0 MB    |            |   0%
# glib-2.56.2          | 5.0 MB    | #########  |  91%
# glib-2.56.2          | 5.0 MB    | ########## | 100%
#
# qt-5.9.6             | 86.7 MB   |            |   0%
# qt-5.9.6             | 86.7 MB   | 3          |   3%
# qt-5.9.6             | 86.7 MB   | #2         |  12%
# qt-5.9.6             | 86.7 MB   | ##1        |  22%
# qt-5.9.6             | 86.7 MB   | ###2       |  33%
# qt-5.9.6             | 86.7 MB   | ####4      |  45%
# qt-5.9.6             | 86.7 MB   | #####5     |  55%
# qt-5.9.6             | 86.7 MB   | ######6    |  67%
# qt-5.9.6             | 86.7 MB   | #######9   |  79%
# qt-5.9.6             | 86.7 MB   | #########1 |  92%
#
# qt-5.9.6             | 86.7 MB   | ########## | 100%
#
# kiwisolver-1.2.0     | 91 KB     |            |   0%
# kiwisolver-1.2.0     | 91 KB     | ########## | 100%
#
# pcre-8.44            | 269 KB    |            |   0%
# pcre-8.44            | 269 KB    | ########## | 100%
#
# sqlite-3.23.1        | 1.5 MB    |            |   0%
# sqlite-3.23.1        | 1.5 MB    | ########## | 100%
# sqlite-3.23.1        | 1.5 MB    | ########## | 100%
#
# xz-5.2.5             | 438 KB    |            |   0%
# xz-5.2.5             | 438 KB    | ########## | 100%
# xz-5.2.5             | 438 KB    | ########## | 100%
#
# libffi-3.2.1         | 52 KB     |            |   0%
# libffi-3.2.1         | 52 KB     | ########## | 100%
#
# mkl_fft-1.2.0        | 164 KB    |            |   0%
# mkl_fft-1.2.0        | 164 KB    | ########## | 100%
#
# jupyter_core-4.6.3   | 75 KB     |            |   0%
# jupyter_core-4.6.3   | 75 KB     | ########## | 100%
#
# olefile-0.46         | 48 KB     |            |   0%
# olefile-0.46         | 48 KB     | ########## | 100%
#
# mkl-2019.4           | 204.1 MB  |            |   0%
# mkl-2019.4           | 204.1 MB  | 2          |   3%
# mkl-2019.4           | 204.1 MB  | 7          |   8%
# mkl-2019.4           | 204.1 MB  | #2         |  13%
# mkl-2019.4           | 204.1 MB  | #7         |  18%
# mkl-2019.4           | 204.1 MB  | ##3        |  23%
# mkl-2019.4           | 204.1 MB  | ##8        |  28%
# mkl-2019.4           | 204.1 MB  | ###3       |  33%
# mkl-2019.4           | 204.1 MB  | ###8       |  38%
# mkl-2019.4           | 204.1 MB  | ####3      |  43%
# mkl-2019.4           | 204.1 MB  | ####8      |  48%
# mkl-2019.4           | 204.1 MB  | #####3     |  53%
# mkl-2019.4           | 204.1 MB  | #####7     |  58%
# mkl-2019.4           | 204.1 MB  | ######2    |  62%
# mkl-2019.4           | 204.1 MB  | ######7    |  67%
# mkl-2019.4           | 204.1 MB  | #######2   |  72%
# mkl-2019.4           | 204.1 MB  | #######7   |  77%
# mkl-2019.4           | 204.1 MB  | ########2  |  82%
# mkl-2019.4           | 204.1 MB  | ########7  |  87%
# mkl-2019.4           | 204.1 MB  | #########1 |  92%
# mkl-2019.4           | 204.1 MB  | #########6 |  96%
#
# mkl-2019.4           | 204.1 MB  | ########## | 100%
#
# libpng-1.6.37        | 364 KB    |            |   0%
# libpng-1.6.37        | 364 KB    | ########## | 100%
# libpng-1.6.37        | 364 KB    | ########## | 100%
#
# libedit-3.1          | 171 KB    |            |   0%
# libedit-3.1          | 171 KB    | ########## | 100%
#
# threadpoolctl-2.1.0  | 16 KB     |            |   0%
# threadpoolctl-2.1.0  | 16 KB     | ########## | 100%
#
# libstdcxx-ng-9.1.0   | 4.0 MB    |            |   0%
# libstdcxx-ng-9.1.0   | 4.0 MB    | ########## | 100%
# libstdcxx-ng-9.1.0   | 4.0 MB    | ########## | 100%
#
# intel-openmp-2020.2  | 947 KB    |            |   0%
# intel-openmp-2020.2  | 947 KB    | ########## | 100%
# intel-openmp-2020.2  | 947 KB    | ########## | 100%
#
# ca-certificates-2020 | 128 KB    |            |   0%
# ca-certificates-2020 | 128 KB    | ########## | 100%
#
# pillow-8.0.0         | 675 KB    |            |   0%
# pillow-8.0.0         | 675 KB    | ########## | 100%
# pillow-8.0.0         | 675 KB    | ########## | 100%
#
# six-1.15.0           | 13 KB     |            |   0%
# six-1.15.0           | 13 KB     | ########## | 100%
#
# wheel-0.35.1         | 36 KB     |            |   0%
# wheel-0.35.1         | 36 KB     | ########## | 100%
#
# ptyprocess-0.6.0     | 23 KB     |            |   0%
# ptyprocess-0.6.0     | 23 KB     | ########## | 100%
#
# matplotlib-base-3.3. | 6.7 MB    |            |   0%
# matplotlib-base-3.3. | 6.7 MB    | ########## | 100%
# matplotlib-base-3.3. | 6.7 MB    | ########## | 100%
#
# cycler-0.10.0        | 13 KB     |            |   0%
# cycler-0.10.0        | 13 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Installing pip dependencies: ...working...
# Ran pip subprocess with arguments:
# ['/azureml-envs/azureml_28b0d742a4cb5c02a5befb218632cd1a/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv.39brink7.requirements.txt']
# Pip subprocess output:
# Collecting azureml-defaults~=1.27.0
#   Downloading azureml_defaults-1.27.0-py3-none-any.whl (3.1 kB)
# Collecting azureml-dataprep[pandas]
#   Downloading azureml_dataprep-2.17.0-py3-none-any.whl (39.4 MB)
# Collecting pyarrow
#   Downloading pyarrow-4.0.1-cp36-cp36m-manylinux2014_x86_64.whl (21.9 MB)
# Collecting azureml-core~=1.27.0
#   Downloading azureml_core-1.27.0.post1-py3-none-any.whl (2.2 MB)
# Collecting azureml-model-management-sdk==1.0.1b6.post1
#   Downloading azureml_model_management_sdk-1.0.1b6.post1-py2.py3-none-any.whl (130 kB)
# Collecting json-logging-py==0.2
#   Downloading json-logging-py-0.2.tar.gz (3.6 kB)
# Collecting azureml-dataset-runtime[fuse]~=1.27.0
#   Downloading azureml_dataset_runtime-1.27.0-py3-none-any.whl (3.4 kB)
# Collecting werkzeug<=1.0.1,>=0.16.1
#   Downloading Werkzeug-1.0.1-py2.py3-none-any.whl (298 kB)
# Collecting gunicorn==19.9.0
#   Downloading gunicorn-19.9.0-py2.py3-none-any.whl (112 kB)
# Collecting configparser==3.7.4
#   Downloading configparser-3.7.4-py2.py3-none-any.whl (22 kB)
# Collecting flask==1.0.3
#   Downloading Flask-1.0.3-py2.py3-none-any.whl (92 kB)
# Collecting applicationinsights>=0.11.7
#   Downloading applicationinsights-0.11.10-py2.py3-none-any.whl (55 kB)
# Collecting dotnetcore2<3.0.0,>=2.1.14
#   Downloading dotnetcore2-2.1.20-py3-none-manylinux1_x86_64.whl (28.7 MB)
# Collecting cloudpickle<2.0.0,>=1.1.0
#   Downloading cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Collecting azureml-dataprep-native<36.0.0,>=35.0.0
#   Downloading azureml_dataprep_native-35.0.0-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Collecting azureml-dataprep-rslex<1.16.0a,>=1.15.0dev0
#   Downloading azureml_dataprep_rslex-1.15.0-cp36-cp36m-manylinux1_x86_64.whl (84.0 MB)
# Collecting azure-identity<1.5.0,>=1.2.0
#   Downloading azure_identity-1.4.1-py2.py3-none-any.whl (86 kB)
# Requirement already satisfied, skipping upgrade: pandas<2.0.0,>=0.23.4; extra == "pandas" in /azureml-envs/azureml_28b0d742a4cb5c02a5befb218632cd1a/lib/python3.6/site-packages (from azureml-dataprep[pandas]->-r /azureml-environment-setup/condaenv.39brink7.requirements.txt (line 2)) (1.1.3)
# Requirement already satisfied, skipping upgrade: numpy<2.0.0,>=1.14.0; extra == "pandas" in /azureml-envs/azureml_28b0d742a4cb5c02a5befb218632cd1a/lib/python3.6/site-packages (from azureml-dataprep[pandas]->-r /azureml-environment-setup/condaenv.39brink7.requirements.txt (line 2)) (1.19.1)
# Requirement already satisfied, skipping upgrade: pytz in /azureml-envs/azureml_28b0d742a4cb5c02a5befb218632cd1a/lib/python3.6/site-packages (from azureml-core~=1.27.0->azureml-defaults~=1.27.0->-r /azureml-environment-setup/condaenv.39brink7.requirements.txt (line 1)) (2020.1)
# Collecting msrestazure>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Collecting PyJWT<3.0.0
#   Downloading PyJWT-2.1.0-py3-none-any.whl (16 kB)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Downloading azure_mgmt_containerregistry-8.0.0-py2.py3-none-any.whl (663 kB)
# Collecting ndg-httpsclient
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting contextlib2<1.0.0
#   Downloading contextlib2-0.6.0.post1-py2.py3-none-any.whl (9.8 kB)
# Collecting SecretStorage<4.0.0
#   Downloading SecretStorage-3.3.1-py3-none-any.whl (15 kB)
# Collecting azure-mgmt-authorization<1.0.0,>=0.40.0
#   Downloading azure_mgmt_authorization-0.61.0-py2.py3-none-any.whl (94 kB)
# Collecting azure-mgmt-storage<16.0.0,>=1.5.0
#   Downloading azure_mgmt_storage-11.2.0-py2.py3-none-any.whl (547 kB)
# Collecting azure-mgmt-keyvault<7.0.0,>=0.40.0
#   Downloading azure_mgmt_keyvault-2.2.0-py2.py3-none-any.whl (89 kB)
# Collecting pathspec<1.0.0
#   Downloading pathspec-0.8.1-py2.py3-none-any.whl (28 kB)
# Collecting ruamel.yaml<0.17.5,>=0.15.35
#   Downloading ruamel.yaml-0.17.4-py3-none-any.whl (101 kB)
# Requirement already satisfied, skipping upgrade: python-dateutil<3.0.0,>=2.7.3 in /azureml-envs/azureml_28b0d742a4cb5c02a5befb218632cd1a/lib/python3.6/site-packages (from azureml-core~=1.27.0->azureml-defaults~=1.27.0->-r /azureml-environment-setup/condaenv.39brink7.requirements.txt (line 1)) (2.8.1)
# Collecting adal>=1.2.0
#   Downloading adal-1.2.7-py2.py3-none-any.whl (55 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting msrest<1.0.0,>=0.5.1
#   Downloading msrest-0.6.21-py2.py3-none-any.whl (85 kB)
# Collecting requests<3.0.0,>=2.19.1
#   Downloading requests-2.25.1-py2.py3-none-any.whl (61 kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<4.0.0
#   Downloading cryptography-3.4.7-cp36-abi3-manylinux2014_x86_64.whl (3.2 MB)
# Collecting jsonpickle<3.0.0
#   Downloading jsonpickle-2.0.0-py2.py3-none-any.whl (37 kB)
# Collecting docker<5.0.0
#   Downloading docker-4.4.4-py2.py3-none-any.whl (147 kB)
# Collecting azure-mgmt-resource<15.0.0,>=1.2.1
#   Downloading azure_mgmt_resource-13.0.0-py2.py3-none-any.whl (1.3 MB)
# Collecting urllib3>=1.23
#   Downloading urllib3-1.26.5-py2.py3-none-any.whl (138 kB)
# Collecting azure-common<2.0.0,>=1.1.12
#   Downloading azure_common-1.1.27-py2.py3-none-any.whl (12 kB)
# Collecting azure-graphrbac<1.0.0,>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting pyopenssl<21.0.0
#   Downloading pyOpenSSL-20.0.1-py2.py3-none-any.whl (54 kB)
# Collecting jmespath<1.0.0
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied, skipping upgrade: six>=1.10 in /azureml-envs/azureml_28b0d742a4cb5c02a5befb218632cd1a/lib/python3.6/site-packages (from azureml-model-management-sdk==1.0.1b6.post1->azureml-defaults~=1.27.0->-r /azureml-environment-setup/condaenv.39brink7.requirements.txt (line 1)) (1.15.0)
# Collecting liac-arff>=2.1.1
#   Downloading liac-arff-2.5.0.tar.gz (13 kB)
# Collecting dill>=0.2.7.1
#   Downloading dill-0.3.3-py2.py3-none-any.whl (81 kB)
# Collecting fusepy<4.0.0,>=3.0.1; extra == "fuse"
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
# Collecting itsdangerous>=0.24
#   Downloading itsdangerous-2.0.1-py3-none-any.whl (18 kB)
# Collecting Jinja2>=2.10
#   Downloading Jinja2-3.0.1-py3-none-any.whl (133 kB)
# Collecting click>=5.1
#   Downloading click-8.0.1-py3-none-any.whl (97 kB)
# Collecting distro>=1.2.0
#   Downloading distro-1.5.0-py2.py3-none-any.whl (18 kB)
# Collecting msal<2.0.0,>=1.3.0
#   Downloading msal-1.12.0-py2.py3-none-any.whl (66 kB)
# Collecting azure-core<2.0.0,>=1.0.0
#   Downloading azure_core-1.14.0-py2.py3-none-any.whl (136 kB)
# Collecting msal-extensions~=0.2.2
#   Downloading msal_extensions-0.2.2-py2.py3-none-any.whl (15 kB)
# Collecting azure-mgmt-core<2.0.0,>=1.2.0
#   Downloading azure_mgmt_core-1.2.2-py2.py3-none-any.whl (21 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting jeepney>=0.6
#   Downloading jeepney-0.6.0-py3-none-any.whl (45 kB)
# Collecting ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.10"
#   Downloading ruamel.yaml.clib-0.2.2-cp36-cp36m-manylinux1_x86_64.whl (549 kB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /azureml-envs/azureml_28b0d742a4cb5c02a5befb218632cd1a/lib/python3.6/site-packages (from msrest<1.0.0,>=0.5.1->azureml-core~=1.27.0->azureml-defaults~=1.27.0->-r /azureml-environment-setup/condaenv.39brink7.requirements.txt (line 1)) (2020.6.20)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Collecting idna<3,>=2.5
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
# Collecting chardet<5,>=3.0.2
#   Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
# Collecting cffi>=1.12
#   Downloading cffi-1.14.5-cp36-cp36m-manylinux1_x86_64.whl (401 kB)
# Collecting importlib-metadata; python_version < "3.8"
#   Downloading importlib_metadata-4.4.0-py3-none-any.whl (17 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-1.0.1-py2.py3-none-any.whl (68 kB)
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.0.1-cp36-cp36m-manylinux2010_x86_64.whl (30 kB)
# Collecting portalocker~=1.0; platform_system != "Windows"
#   Downloading portalocker-1.7.1-py2.py3-none-any.whl (10 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Collecting pycparser
#   Downloading pycparser-2.20-py2.py3-none-any.whl (112 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.4.1-py3-none-any.whl (5.2 kB)
# Collecting typing-extensions>=3.6.4; python_version < "3.8"
#   Downloading typing_extensions-3.10.0.0-py3-none-any.whl (26 kB)
# Building wheels for collected packages: json-logging-py, liac-arff, fusepy
#   Building wheel for json-logging-py (setup.py): started
#   Building wheel for json-logging-py (setup.py): finished with status 'done'
#   Created wheel for json-logging-py: filename=json_logging_py-0.2-py3-none-any.whl size=3924 sha256=c3b63b1536244caa7f475af5482934ce13b9c2c4b62d13948a5a9b6ee2b916d7
#   Stored in directory: /root/.cache/pip/wheels/e2/1d/52/535a274b9c2ce7d4064838f2bdb62013801281ef7d7f21e2ee
#   Building wheel for liac-arff (setup.py): started
#   Building wheel for liac-arff (setup.py): finished with status 'done'
#   Created wheel for liac-arff: filename=liac_arff-2.5.0-py3-none-any.whl size=11730 sha256=e8c0586a4d40b48e219a4de3794cce22a1c9aa7a422248d99b0bb0593406d887
#   Stored in directory: /root/.cache/pip/wheels/53/ba/da/8562a6a6dbb428fd1ecc21053106df3948645cd991958f669b
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10504 sha256=03964c90cce2167f0883c90976055231b386dc3c45ae40a8fc0c2a9a66dcacfe
#   Stored in directory: /root/.cache/pip/wheels/21/5c/83/1dd7e8a232d12227e5410120f4374b33adeb4037473105b079
# Successfully built json-logging-py liac-arff fusepy
# Installing collected packages: pycparser, cffi, cryptography, PyJWT, idna, urllib3, chardet, requests, adal, oauthlib, requests-oauthlib, isodate, msrest, msrestazure, azure-common, azure-core, azure-mgmt-core, azure-mgmt-containerregistry, pyasn1, pyopenssl, ndg-httpsclient, contextlib2, jeepney, SecretStorage, azure-mgmt-authorization, azure-mgmt-storage, azure-mgmt-keyvault, pathspec, ruamel.yaml.clib, ruamel.yaml, backports.weakref, backports.tempfile, zipp, typing-extensions, importlib-metadata, jsonpickle, websocket-client, docker, azure-mgmt-resource, azure-graphrbac, jmespath, azureml-core, liac-arff, dill, azureml-model-management-sdk, json-logging-py, distro, dotnetcore2, cloudpickle, azureml-dataprep-native, azureml-dataprep-rslex, msal, portalocker, msal-extensions, azure-identity, pyarrow, azureml-dataprep, fusepy, azureml-dataset-runtime, werkzeug, gunicorn, configparser, itsdangerous, MarkupSafe, Jinja2, click, flask, applicationinsights, azureml-defaults
# Successfully installed Jinja2-3.0.1 MarkupSafe-2.0.1 PyJWT-2.1.0 SecretStorage-3.3.1 adal-1.2.7 applicationinsights-0.11.10 azure-common-1.1.27 azure-core-1.14.0 azure-graphrbac-0.61.1 azure-identity-1.4.1 azure-mgmt-authorization-0.61.0 azure-mgmt-containerregistry-8.0.0 azure-mgmt-core-1.2.2 azure-mgmt-keyvault-2.2.0 azure-mgmt-resource-13.0.0 azure-mgmt-storage-11.2.0 azureml-core-1.27.0.post1 azureml-dataprep-2.17.0 azureml-dataprep-native-35.0.0 azureml-dataprep-rslex-1.15.0 azureml-dataset-runtime-1.27.0 azureml-defaults-1.27.0 azureml-model-management-sdk-1.0.1b6.post1 backports.tempfile-1.0 backports.weakref-1.0.post1 cffi-1.14.5 chardet-4.0.0 click-8.0.1 cloudpickle-1.6.0 configparser-3.7.4 contextlib2-0.6.0.post1 cryptography-3.4.7 dill-0.3.3 distro-1.5.0 docker-4.4.4 dotnetcore2-2.1.20 flask-1.0.3 fusepy-3.0.1 gunicorn-19.9.0 idna-2.10 importlib-metadata-4.4.0 isodate-0.6.0 itsdangerous-2.0.1 jeepney-0.6.0 jmespath-0.10.0 json-logging-py-0.2 jsonpickle-2.0.0 liac-arff-2.5.0 msal-1.12.0 msal-extensions-0.2.2 msrest-0.6.21 msrestazure-0.6.4 ndg-httpsclient-0.5.1 oauthlib-3.1.0 pathspec-0.8.1 portalocker-1.7.1 pyarrow-4.0.1 pyasn1-0.4.8 pycparser-2.20 pyopenssl-20.0.1 requests-2.25.1 requests-oauthlib-1.3.0 ruamel.yaml-0.17.4 ruamel.yaml.clib-0.2.2 typing-extensions-3.10.0.0 urllib3-1.26.5 websocket-client-1.0.1 werkzeug-1.0.1 zipp-3.4.1
#
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 4.10.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
# #
# # To activate this environment, use
# #
# #     $ conda activate /azureml-envs/azureml_28b0d742a4cb5c02a5befb218632cd1a
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
# WARNING: /root/.conda/pkgs does not exist
# Removing intermediate container da0feec03dbf
#  ---> 7e8146aa15bf
# Step 9/18 : ENV PATH /azureml-envs/azureml_28b0d742a4cb5c02a5befb218632cd1a/bin:$PATH
#  ---> Running in 49e4a3689c21
# Removing intermediate container 49e4a3689c21
#  ---> 4844c05f297b
# Step 10/18 : COPY azureml-environment-setup/send_conda_dependencies.py azureml-environment-setup/send_conda_dependencies.py
#  ---> e45a34c8e050
# Step 11/18 : COPY azureml-environment-setup/environment_context.json azureml-environment-setup/environment_context.json
#  ---> 9d1c7ee1475e
# Step 12/18 : RUN python /azureml-environment-setup/send_conda_dependencies.py -p /azureml-envs/azureml_28b0d742a4cb5c02a5befb218632cd1a
#  ---> Running in 66e687a18924
# Report materialized dependencies for the environment
# Reading environment context
# Exporting conda environment
# Sending request with materialized conda environment details
# Successfully sent materialized environment details
# Removing intermediate container 66e687a18924
#  ---> 7b86f487f6bc
# Step 13/18 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_28b0d742a4cb5c02a5befb218632cd1a
#  ---> Running in d34a94bbef2c
# Removing intermediate container d34a94bbef2c
#  ---> a426bed291ac
# Step 14/18 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_28b0d742a4cb5c02a5befb218632cd1a/lib:$LD_LIBRARY_PATH
#  ---> Running in 736d72b42ddd
# Removing intermediate container 736d72b42ddd
#  ---> 2ac0370ac6ce
# Step 15/18 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> 13b0d869fc7d
# Step 16/18 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in 0d67ec0f53d0
# Removing intermediate container 0d67ec0f53d0
#  ---> 2fba3c2afa83
# Step 17/18 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in 1e08890fa126
# Removing intermediate container 1e08890fa126
#  ---> ba89a018cf41
# Step 18/18 : CMD ["bash"]
#  ---> Running in 6f05ab47ef9d
# Removing intermediate container 6f05ab47ef9d
#  ---> acd3cdbb5968
# Successfully built acd3cdbb5968
# Successfully tagged a17537c43d7f425dabe668516b2725e3.azurecr.io/azureml/azureml_443e6f417ae4fd3295e21acd32219350:latest
# Successfully tagged a17537c43d7f425dabe668516b2725e3.azurecr.io/azureml/azureml_443e6f417ae4fd3295e21acd32219350:1
# 2021/05/31 21:37:09 Successfully executed container: acb_step_0
# 2021/05/31 21:37:09 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/05/31 21:37:09 Pushing image: a17537c43d7f425dabe668516b2725e3.azurecr.io/azureml/azureml_443e6f417ae4fd3295e21acd32219350:1, attempt 1
# The push refers to repository [a17537c43d7f425dabe668516b2725e3.azurecr.io/azureml/azureml_443e6f417ae4fd3295e21acd32219350]
# 416f69149865: Preparing
# 1e0f446f610a: Preparing
# 9312f6a36407: Preparing
# b4e5d061b9fb: Preparing
# 5ac82d72f561: Preparing
# 5dc9cecbfb02: Preparing
# fb0c7056cf61: Preparing
# 20890d56cae2: Preparing
# ce5fe2d308d3: Preparing
# 3f3f8889d538: Preparing
# 420340de7040: Preparing
# c3d9b0d7dd4c: Preparing
# 4441896e1280: Preparing
# a64fe594a899: Preparing
# 0d34930f20d5: Preparing
# 18c9012f327d: Preparing
# e4a0bf630548: Preparing
# 5276d2b930fc: Preparing
# e6feec0db89a: Preparing
# 697949baa658: Preparing
# 935c56d8b3f9: Preparing
# 5dc9cecbfb02: Waiting
# fb0c7056cf61: Waiting
# 20890d56cae2: Waiting
# ce5fe2d308d3: Waiting
# 3f3f8889d538: Waiting
# 420340de7040: Waiting
# c3d9b0d7dd4c: Waiting
# 4441896e1280: Waiting
# a64fe594a899: Waiting
# 0d34930f20d5: Waiting
# 18c9012f327d: Waiting
# e4a0bf630548: Waiting
# 5276d2b930fc: Waiting
# e6feec0db89a: Waiting
# 697949baa658: Waiting
# 935c56d8b3f9: Waiting
# 9312f6a36407: Pushed
# 416f69149865: Pushed
# b4e5d061b9fb: Pushed
# 1e0f446f610a: Pushed
# 5dc9cecbfb02: Pushed
# fb0c7056cf61: Pushed
# 20890d56cae2: Pushed
# ce5fe2d308d3: Pushed
# 3f3f8889d538: Pushed
# 420340de7040: Pushed
# c3d9b0d7dd4c: Pushed
# 18c9012f327d: Pushed
# 0d34930f20d5: Pushed
# 4441896e1280: Pushed
# e6feec0db89a: Pushed
# 5276d2b930fc: Pushed
# 697949baa658: Pushed
# a64fe594a899: Pushed
# 935c56d8b3f9: Pushed
# e4a0bf630548: Pushed
# 5ac82d72f561: Pushed
# 1: digest: sha256:a6ebc084ca66ee2d6c7e5e77e4404a9325ca0c5120521fc158d7324c7131a218 size: 4721
# 2021/05/31 21:40:31 Successfully pushed image: a17537c43d7f425dabe668516b2725e3.azurecr.io/azureml/azureml_443e6f417ae4fd3295e21acd32219350:1
# 2021/05/31 21:40:31 Executing step ID: acb_step_2. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/05/31 21:40:31 Pushing image: a17537c43d7f425dabe668516b2725e3.azurecr.io/azureml/azureml_443e6f417ae4fd3295e21acd32219350:latest, attempt 1
# The push refers to repository [a17537c43d7f425dabe668516b2725e3.azurecr.io/azureml/azureml_443e6f417ae4fd3295e21acd32219350]
# 416f69149865: Preparing
# 1e0f446f610a: Preparing
# 9312f6a36407: Preparing
# b4e5d061b9fb: Preparing
# 5ac82d72f561: Preparing
# 5dc9cecbfb02: Preparing
# fb0c7056cf61: Preparing
# 20890d56cae2: Preparing
# ce5fe2d308d3: Preparing
# 3f3f8889d538: Preparing
# 420340de7040: Preparing
# c3d9b0d7dd4c: Preparing
# 4441896e1280: Preparing
# a64fe594a899: Preparing
# 0d34930f20d5: Preparing
# 18c9012f327d: Preparing
# e4a0bf630548: Preparing
# 5276d2b930fc: Preparing
# e6feec0db89a: Preparing
# 697949baa658: Preparing
# 935c56d8b3f9: Preparing
# c3d9b0d7dd4c: Waiting
# 4441896e1280: Waiting
# a64fe594a899: Waiting
# 0d34930f20d5: Waiting
# 18c9012f327d: Waiting
# e4a0bf630548: Waiting
# 5276d2b930fc: Waiting
# e6feec0db89a: Waiting
# 697949baa658: Waiting
# 935c56d8b3f9: Waiting
# 5dc9cecbfb02: Waiting
# fb0c7056cf61: Waiting
# 20890d56cae2: Waiting
# ce5fe2d308d3: Waiting
# 3f3f8889d538: Waiting
# 420340de7040: Waiting
# 5ac82d72f561: Layer already exists
# 416f69149865: Layer already exists
# 9312f6a36407: Layer already exists
# 1e0f446f610a: Layer already exists
# 5dc9cecbfb02: Layer already exists
# b4e5d061b9fb: Layer already exists
# 20890d56cae2: Layer already exists
# fb0c7056cf61: Layer already exists
# ce5fe2d308d3: Layer already exists
# c3d9b0d7dd4c: Layer already exists
# 3f3f8889d538: Layer already exists
# 420340de7040: Layer already exists
# 4441896e1280: Layer already exists
# 0d34930f20d5: Layer already exists
# a64fe594a899: Layer already exists
# e4a0bf630548: Layer already exists
# 5276d2b930fc: Layer already exists
# 18c9012f327d: Layer already exists
# e6feec0db89a: Layer already exists
# 697949baa658: Layer already exists
# 935c56d8b3f9: Layer already exists
# latest: digest: sha256:a6ebc084ca66ee2d6c7e5e77e4404a9325ca0c5120521fc158d7324c7131a218 size: 4721
# 2021/05/31 21:40:37 Successfully pushed image: a17537c43d7f425dabe668516b2725e3.azurecr.io/azureml/azureml_443e6f417ae4fd3295e21acd32219350:latest
# 2021/05/31 21:40:37 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 365.317038)
# 2021/05/31 21:40:37 Populating digests for step ID: acb_step_0...
# 2021/05/31 21:40:41 Successfully populated digests for step ID: acb_step_0
# 2021/05/31 21:40:41 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 201.679842)
# 2021/05/31 21:40:41 Step ID: acb_step_2 marked as successful (elapsed time in seconds: 6.591709)
# 2021/05/31 21:40:41 The following dependencies were found:
# 2021/05/31 21:40:41
# - image:
#     registry: a17537c43d7f425dabe668516b2725e3.azurecr.io
#     repository: azureml/azureml_443e6f417ae4fd3295e21acd32219350
#     tag: latest
#     digest: sha256:a6ebc084ca66ee2d6c7e5e77e4404a9325ca0c5120521fc158d7324c7131a218
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/intelmpi2018.3-ubuntu16.04
#     tag: 20210301.v1
#     digest: sha256:000d6c43f606ceaa67983790ca95c70fd741c364d8c2e3217a11d775b99741df
#   git: {}
# - image:
#     registry: a17537c43d7f425dabe668516b2725e3.azurecr.io
#     repository: azureml/azureml_443e6f417ae4fd3295e21acd32219350
#     tag: "1"
#     digest: sha256:a6ebc084ca66ee2d6c7e5e77e4404a9325ca0c5120521fc158d7324c7131a218
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/intelmpi2018.3-ubuntu16.04
#     tag: 20210301.v1
#     digest: sha256:000d6c43f606ceaa67983790ca95c70fd741c364d8c2e3217a11d775b99741df
#   git: {}
#
#
# Run ID: cc3 was successful after 9m43s
#
# Streaming azureml-logs/55_azureml-execution-tvmps_447b7d88c5a25e1abf12dfe3ceaf19b6180fbfba013d8d9d61155442bce55907_d.txt
# ========================================================================================================================
# 2021-05-31T21:44:52Z Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/aml-revision/azureml/161ac072-e7b6-4525-9af1-36d3979aee4a/mounts/workspaceblobstore
# 2021-05-31T21:44:53Z Starting output-watcher...
# 2021-05-31T21:44:53Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2021-05-31T21:44:53Z Executing 'Copy ACR Details file' on 10.0.0.4
# 2021-05-31T21:44:53Z Copy ACR Details file succeeded on 10.0.0.4. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_443e6f417ae4fd3295e21acd32219350
# 4007a89234b4: Pulling fs layer
# 5dfa26c6b9c9: Pulling fs layer
# 0ba7bf18aa40: Pulling fs layer
# 4c6ec688ebe3: Pulling fs layer
# 574f361512d6: Pulling fs layer
# db4d1e2d7079: Pulling fs layer
# e544ee0f522d: Pulling fs layer
# c655136086be: Pulling fs layer
# 2ec37f44090c: Pulling fs layer
# 5fba3bd4a2c4: Pulling fs layer
# 7e0ea9d0a1ab: Pulling fs layer
# da005f826951: Pulling fs layer
# a9f9325cb701: Pulling fs layer
# 6d355ad35efb: Pulling fs layer
# c119a4ac1e69: Pulling fs layer
# cd404fd17893: Pulling fs layer
# 2e5af136d8c5: Pulling fs layer
# c4b6889cf850: Pulling fs layer
# fc76e4497951: Pulling fs layer
# 3edf87a2f30a: Pulling fs layer
# 00f9433cef8d: Pulling fs layer
# da005f826951: Waiting
# a9f9325cb701: Waiting
# 6d355ad35efb: Waiting
# c119a4ac1e69: Waiting
# cd404fd17893: Waiting
# 2e5af136d8c5: Waiting
# c4b6889cf850: Waiting
# fc76e4497951: Waiting
# 3edf87a2f30a: Waiting
# 00f9433cef8d: Waiting
# 4c6ec688ebe3: Waiting
# 574f361512d6: Waiting
# db4d1e2d7079: Waiting
# e544ee0f522d: Waiting
# c655136086be: Waiting
# 2ec37f44090c: Waiting
# 5fba3bd4a2c4: Waiting
# 7e0ea9d0a1ab: Waiting
# 0ba7bf18aa40: Verifying Checksum
# 0ba7bf18aa40: Download complete
# 5dfa26c6b9c9: Verifying Checksum
# 5dfa26c6b9c9: Download complete
# 4c6ec688ebe3: Verifying Checksum
# 4c6ec688ebe3: Download complete
# 4007a89234b4: Verifying Checksum
# 4007a89234b4: Download complete
# db4d1e2d7079: Verifying Checksum
# db4d1e2d7079: Download complete
# e544ee0f522d: Verifying Checksum
# e544ee0f522d: Download complete
# 574f361512d6: Verifying Checksum
# 574f361512d6: Download complete
# c655136086be: Verifying Checksum
# c655136086be: Download complete
# 7e0ea9d0a1ab: Verifying Checksum
# 7e0ea9d0a1ab: Download complete
# 5fba3bd4a2c4: Verifying Checksum
# 5fba3bd4a2c4: Download complete
# 2ec37f44090c: Verifying Checksum
# 2ec37f44090c: Download complete
# a9f9325cb701: Verifying Checksum
# a9f9325cb701: Download complete
# da005f826951: Download complete
# c119a4ac1e69: Verifying Checksum
# c119a4ac1e69: Download complete
# cd404fd17893: Verifying Checksum
# cd404fd17893: Download complete
# c4b6889cf850: Verifying Checksum
# c4b6889cf850: Download complete
# 6d355ad35efb: Verifying Checksum
# 6d355ad35efb: Download complete
# fc76e4497951: Verifying Checksum
# fc76e4497951: Download complete
# 3edf87a2f30a: Verifying Checksum
# 3edf87a2f30a: Download complete
# 00f9433cef8d: Verifying Checksum
# 00f9433cef8d: Download complete
# 4007a89234b4: Pull complete
# 5dfa26c6b9c9: Pull complete
# 0ba7bf18aa40: Pull complete
# 4c6ec688ebe3: Pull complete
# 2e5af136d8c5: Verifying Checksum
# 2e5af136d8c5: Download complete
# 574f361512d6: Pull complete
# db4d1e2d7079: Pull complete
# e544ee0f522d: Pull complete
# c655136086be: Pull complete
# 2ec37f44090c: Pull complete
# 5fba3bd4a2c4: Pull complete
# 7e0ea9d0a1ab: Pull complete
# da005f826951: Pull complete
# a9f9325cb701: Pull complete
# 6d355ad35efb: Pull complete
# c119a4ac1e69: Pull complete
# cd404fd17893: Pull complete
# 2e5af136d8c5: Pull complete
# c4b6889cf850: Pull complete
# fc76e4497951: Pull complete
# 3edf87a2f30a: Pull complete
# 00f9433cef8d: Pull complete
# Digest: sha256:a6ebc084ca66ee2d6c7e5e77e4404a9325ca0c5120521fc158d7324c7131a218
# Status: Downloaded newer image for a17537c43d7f425dabe668516b2725e3.azurecr.io/azureml/azureml_443e6f417ae4fd3295e21acd32219350:latest
# a17537c43d7f425dabe668516b2725e3.azurecr.io/azureml/azureml_443e6f417ae4fd3295e21acd32219350:latest
# 2021-05-31T21:45:50Z Check if container 161ac072-e7b6-4525-9af1-36d3979aee4a already exist exited with 0,
#
# c02304d62b45ce30580eeb0a7b7e697915f53e576127fb7a77998a2e3b3d4a36
# 2021-05-31T21:45:54Z Parameters for containerSetup task: useDetonationChamer set to false and sshRequired set to false
# 2021-05-31T21:45:54Z containerSetup task cmd: [/mnt/batch/tasks/startup/wd/hosttools -task=containerSetup -traceContext=00-e361cfe8eb039d902663a2d6322360ab-99e3a6941c130803-01 -sshRequired=false]
# 2021/05/31 21:45:54 Starting App Insight Logger for task:  containerSetup
# 2021/05/31 21:45:54 Version: 3.0.01601.0003 Branch: 2021-05-21 Commit: 6f99cdc
# 2021/05/31 21:45:54 Entered ContainerSetupTask - Preparing infiniband
# 2021/05/31 21:45:54 Starting infiniband setup
# 2021/05/31 21:45:54 Python Version found is Python 3.6.2 :: Anaconda, Inc.
#
# 2021/05/31 21:45:54 Returning Python Version as 3.6
# 2021/05/31 21:45:54 VMSize: standard_ds11_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-16.04
# 2021/05/31 21:45:54 VMSize: standard_ds11_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-16.04
# 2021-05-31T21:45:54Z VMSize: standard_ds11_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-16.04
# 2021/05/31 21:45:54 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2021/05/31 21:45:54 Not setting up Infiniband in Container
# 2021/05/31 21:45:54 Not setting up Infiniband in Container
# 2021-05-31T21:45:54Z Not setting up Infiniband in Container
# 2021/05/31 21:45:54 Python Version found is Python 3.6.2 :: Anaconda, Inc.
#
# 2021/05/31 21:45:54 Returning Python Version as 3.6
# 2021/05/31 21:45:54 sshd inside container not required for job, skipping setup.
# 2021/05/31 21:45:54 All App Insights Logs was send successfully
# 2021/05/31 21:45:54 App Insight Client has already been closed
# 2021/05/31 21:45:54 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 1
# FilteredData: 0.
# 2021-05-31T21:45:54Z Starting docker container succeeded.
# 2021-05-31T21:45:58Z Job environment preparation succeeded on 10.0.0.4. Output:
# >>>   2021/05/31 21:44:51 Starting App Insight Logger for task:  prepareJobEnvironment
# >>>   2021/05/31 21:44:51 Version: 3.0.01601.0003 Branch: 2021-05-21 Commit: 6f99cdc
# >>>   2021/05/31 21:44:51 runtime.GOOS linux
# >>>   2021/05/31 21:44:51 Checking if '/tmp' exists
# >>>   2021/05/31 21:44:51 Reading dyanamic configs
# >>>   2021/05/31 21:44:51 Container sas url: https://baiscriptswestus2prod.blob.core.windows.net/aihosttools?sv=2018-03-28&sr=c&si=aihosttoolspolicy&sig=71Fsy25bPMdce8Lc7jVPFZbJokMhH4i%2F250OyAEdREA%3D
# >>>   2021/05/31 21:44:51 Failed to read from file /mnt/batch/tasks/startup/wd/az_resource/xdsenv.variable/azsecpack.variables, open /mnt/batch/tasks/startup/wd/az_resource/xdsenv.variable/azsecpack.variables: no such file or directory
# >>>   2021/05/31 21:44:51 [in autoUpgradeFromJobNodeSetup] Is Azsecpack installer on host: false. Is Azsecpack enabled: false,
# >>>   2021/05/31 21:44:51 Starting Azsecpack installation on machine: 8ec605badcae450e9a705ff72352e2e1000000#798d0da9-368e-472e-83b1-e8d76c71d339#ecdf148e-e3eb-433a-9970-91b083980992#aml-resources-2#aml-revision#azcompcluster
# >>>   2021/05/31 21:44:51 Is Azsecpack enabled: false, GetDisableVsatlsscan: true
# >>>   2021/05/31 21:44:51 Turning off azsecpack, if it is already running
# >>>   2021/05/31 21:44:51 [doTurnOffAzsecpack] output:Unit mdsd.service could not be found.
# >>>   ,err:exit status 1.
# >>>   2021/05/31 21:44:51 OS patching disabled by dynamic configs. Skipping.
# >>>   2021/05/31 21:44:51 Job: AZ_BATCHAI_JOB_NAME does not turn on the DetonationChamber
# >>>   2021/05/31 21:44:51 Start to getting gpu count by running nvidia-smi command
# >>>   2021/05/31 21:44:51 GPU count found on the node: 0
# >>>   2021/05/31 21:44:51 AMLComputeXDSEndpoint:  https://westus2-prodk8ds.batchai.core.windows.net
# >>>   2021/05/31 21:44:51 AMLComputeXDSApiVersion:  2018-02-01
# >>>   2021/05/31 21:44:51 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/aml-revision/azureml/161ac072-e7b6-4525-9af1-36d3979aee4a/config
# >>>   2021/05/31 21:44:51 This is not a aml-workstation (compute instance), current offer type: amlcompute. Starting identity responder as part of prepareJobEnvironment.
# >>>   2021/05/31 21:44:51 Starting identity responder.
# >>>   2021/05/31 21:44:51 Starting identity responder.
# >>>   2021/05/31 21:44:51 Failed to open file /mnt/batch/tasks/shared/LS_root/jobs/aml-revision/azureml/161ac072-e7b6-4525-9af1-36d3979aee4a/config/.batchai.IdentityResponder.envlist: open /mnt/batch/tasks/shared/LS_root/jobs/aml-revision/azureml/161ac072-e7b6-4525-9af1-36d3979aee4a/config/.batchai.IdentityResponder.envlist: no such file or directory
# >>>   2021/05/31 21:44:51 Logfile used for identity responder: /mnt/batch/tasks/workitems/89a8a1fa-2c5c-4b27-b8df-88f359d1a28c/job-1/161ac072-e7b6-4525-9_88ce8f26-6bad-4b44-a80b-9ac952d53073/IdentityResponderLog-tvmps_447b7d88c5a25e1abf12dfe3ceaf19b6180fbfba013d8d9d61155442bce55907_d.txt
# ...
# >>>   2021/05/31 21:46:44 Check if container 9e390739-6b65-41c0-9433-b3f02912b5b9 already exist exited with 0,
# >>>
# >>>   2021/05/31 21:46:44 Check if container 9e390739-6b65-41c0-9433-b3f02912b5b9 already exist exited with 0,
# >>>
# >>>   2021/05/31 21:46:44 Parameters for containerSetup task: useDetonationChamer set to false and sshRequired set to false
# >>>   2021/05/31 21:46:44 Parameters for containerSetup task: useDetonationChamer set to false and sshRequired set to false
# >>>   2021/05/31 21:46:44 containerSetup task cmd: [/mnt/batch/tasks/startup/wd/hosttools -task=containerSetup -traceContext=00-43c7ade99ede7c1895a99d6c72f68a55-c83fc4ec71ccf121-01 -sshRequired=false]
# >>>   2021/05/31 21:46:44 containerSetup task cmd: [/mnt/batch/tasks/startup/wd/hosttools -task=containerSetup -traceContext=00-43c7ade99ede7c1895a99d6c72f68a55-c83fc4ec71ccf121-01 -sshRequired=false]
# >>>   2021/05/31 21:46:45 Container ssh is not required for job type.
# >>>   2021/05/31 21:46:45 Starting docker container succeeded.
# >>>   2021/05/31 21:46:45 Starting docker container succeeded.
# >>>   2021/05/31 21:46:45 Disk space after starting docker container: 22569MB
# >>>   2021/05/31 21:46:45 Begin execution of runSpecialJobTask
# >>>   2021/05/31 21:46:45 runSpecialJobTask: os.GetEnv constants.StdouterrDir: /mnt/batch/tasks/shared/LS_root/jobs/aml-revision/azureml/9e390739-6b65-41c0-9433-b3f02912b5b9/mounts/workspaceblobstore/azureml/9e390739-6b65-41c0-9433-b3f02912b5b9/azureml_compute_logs
# >>>   2021/05/31 21:46:45 runSpecialJobTask: Raw cmd for preparation is passed is: /azureml-envs/azureml_28b0d742a4cb5c02a5befb218632cd1a/bin/python /mnt/batch/tasks/shared/LS_root/jobs/aml-revision/azureml/9e390739-6b65-41c0-9433-b3f02912b5b9/mounts/workspaceblobstore/azureml/9e390739-6b65-41c0-9433-b3f02912b5b9-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"4d0f18fe-1ee4-465e-8c0b-a41eb7f5561c","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2021/05/31 21:46:45 runSpecialJobTask: stdout path for preparation is passed is: /mnt/batch/tasks/shared/LS_root/jobs/aml-revision/azureml/9e390739-6b65-41c0-9433-b3f02912b5b9/mounts/workspaceblobstore/azureml/9e390739-6b65-41c0-9433-b3f02912b5b9/azureml_compute_logs/65_job_prep-tvmps_447b7d88c5a25e1abf12dfe3ceaf19b6180fbfba013d8d9d61155442bce55907_d.txt
# >>>   2021/05/31 21:46:45 runSpecialJobTask: stderr path for preparation is passed is: /mnt/batch/tasks/shared/LS_root/jobs/aml-revision/azureml/9e390739-6b65-41c0-9433-b3f02912b5b9/mounts/workspaceblobstore/azureml/9e390739-6b65-41c0-9433-b3f02912b5b9/azureml_compute_logs/65_job_prep-tvmps_447b7d88c5a25e1abf12dfe3ceaf19b6180fbfba013d8d9d61155442bce55907_d.txt
# >>>   2021/05/31 21:46:45 native cmd: export AZUREML_JOB_TASK_ERROR_PATH='/mnt/batch/tasks/workitems/89a8a1fa-2c5c-4b27-b8df-88f359d1a28c/job-1/9e390739-6b65-41c0-9_9f83ded1-bdec-4e20-ad60-cac891bdc5f2/wd/runSpecialJobTask_error.json';cd /mnt/batch/tasks/shared/LS_root/jobs/aml-revision/azureml/9e390739-6b65-41c0-9433-b3f02912b5b9/mounts/workspaceblobstore/azureml/9e390739-6b65-41c0-9433-b3f02912b5b9;/azureml-envs/azureml_28b0d742a4cb5c02a5befb218632cd1a/bin/python /mnt/batch/tasks/shared/LS_root/jobs/aml-revision/azureml/9e390739-6b65-41c0-9433-b3f02912b5b9/mounts/workspaceblobstore/azureml/9e390739-6b65-41c0-9433-b3f02912b5b9-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"4d0f18fe-1ee4-465e-8c0b-a41eb7f5561c","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2021/05/31 21:46:45 runSpecialJobTask: commons.GetOsPlatform(): ubuntu
# >>>   2021/05/31 21:46:46 runSpecialJobTask: Running cmd: /usr/bin/docker exec -e AZUREML_SDK_TRACEPARENT=00-43c7ade99ede7c1895a99d6c72f68a55-8aad477bfd37bce2-01 -t 9e390739-6b65-41c0-9433-b3f02912b5b9 bash -c if [ -f ~/.bashrc ]; then PS1_back=$PS1; PS1='$'; . ~/.bashrc; PS1=$PS1_back; fi;PATH=$PATH:$AZ_BATCH_NODE_STARTUP_DIR/wd/;export AZUREML_JOB_TASK_ERROR_PATH='/mnt/batch/tasks/workitems/89a8a1fa-2c5c-4b27-b8df-88f359d1a28c/job-1/9e390739-6b65-41c0-9_9f83ded1-bdec-4e20-ad60-cac891bdc5f2/wd/runSpecialJobTask_error.json';cd /mnt/batch/tasks/shared/LS_root/jobs/aml-revision/azureml/9e390739-6b65-41c0-9433-b3f02912b5b9/mounts/workspaceblobstore/azureml/9e390739-6b65-41c0-9433-b3f02912b5b9;/azureml-envs/azureml_28b0d742a4cb5c02a5befb218632cd1a/bin/python /mnt/batch/tasks/shared/LS_root/jobs/aml-revision/azureml/9e390739-6b65-41c0-9433-b3f02912b5b9/mounts/workspaceblobstore/azureml/9e390739-6b65-41c0-9433-b3f02912b5b9-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"4d0f18fe-1ee4-465e-8c0b-a41eb7f5561c","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2021/05/31 21:46:47 Attempt 1 of http call to https://westus2.api.azureml.ms/history/v1.0/private/subscriptions/ecdf148e-e3eb-433a-9970-91b083980992/resourceGroups/aml-resources-2/providers/Microsoft.MachineLearningServices/workspaces/aml-revision/runs/9e390739-6b65-41c0-9433-b3f02912b5b9/spans
# >>>   2021/05/31 21:46:49 runSpecialJobTask: job preparation exited with code 0 and err <nil>
# >>>
# >>>   2021/05/31 21:46:49 runSpecialJobTask: preparation: [2021-05-31T21:46:46.318775] Entering job preparation.
# >>>   2021/05/31 21:46:49 runSpecialJobTask: preparation: [2021-05-31T21:46:47.580381] Starting job preparation.
# >>>   2021/05/31 21:46:49 runSpecialJobTask: preparation: [2021-05-31T21:46:47.580427] Extracting the control code.
# >>>   2021/05/31 21:46:49 runSpecialJobTask: preparation: [2021-05-31T21:46:47.599858] fetching and extracting the control code on master node.
# >>>   2021/05/31 21:46:49 runSpecialJobTask: preparation: [2021-05-31T21:46:47.599915] Starting extract_project.
# >>>   2021/05/31 21:46:49 runSpecialJobTask: preparation: [2021-05-31T21:46:47.599969] Starting to extract zip file.
# >>>   2021/05/31 21:46:49 runSpecialJobTask: preparation: [2021-05-31T21:46:48.008359] Finished extracting zip file.
# >>>   2021/05/31 21:46:49 runSpecialJobTask: preparation: [2021-05-31T21:46:48.280408] Using urllib.request Python 3.0 or later
# >>>   2021/05/31 21:46:49 runSpecialJobTask: preparation: [2021-05-31T21:46:48.280473] Start fetching snapshots.
# >>>   2021/05/31 21:46:49 runSpecialJobTask: preparation: [2021-05-31T21:46:48.280518] Start fetching snapshot.
# >>>   2021/05/31 21:46:49 runSpecialJobTask: preparation: [2021-05-31T21:46:48.280531] Retrieving project from snapshot: 4d0f18fe-1ee4-465e-8c0b-a41eb7f5561c
# >>>   2021/05/31 21:46:49 runSpecialJobTask: preparation: Starting the daemon thread to refresh tokens in background for process with pid = 52
# >>>   2021/05/31 21:46:49 runSpecialJobTask: preparation: [2021-05-31T21:46:48.508613] Finished fetching snapshot.
# >>>   2021/05/31 21:46:49 runSpecialJobTask: preparation: [2021-05-31T21:46:48.508668] Finished fetching snapshots.
# >>>   2021/05/31 21:46:49 runSpecialJobTask: preparation: [2021-05-31T21:46:48.508857] Finished extract_project.
# >>>   2021/05/31 21:46:49 runSpecialJobTask: preparation: [2021-05-31T21:46:48.518820] Finished fetching and extracting the control code.
# >>>   2021/05/31 21:46:49 runSpecialJobTask: preparation: [2021-05-31T21:46:48.524571] Start run_history_prep.
# >>>   2021/05/31 21:46:49 runSpecialJobTask: preparation: [2021-05-31T21:46:48.525211] downloadDataStore - Download from datastores if requested.
# >>>   2021/05/31 21:46:49 runSpecialJobTask: preparation: [2021-05-31T21:46:48.581126] Entering context manager injector.
# >>>   2021/05/31 21:46:49 runSpecialJobTask: preparation: Acquired lockfile /tmp/9e390739-6b65-41c0-9433-b3f02912b5b9-datastore.lock to downloading input data references
# >>>   2021/05/31 21:46:49 runSpecialJobTask: preparation: [2021-05-31T21:46:49.124682] downloadDataStore completed
# >>>   2021/05/31 21:46:49 runSpecialJobTask: preparation: [2021-05-31T21:46:49.127907] Job preparation is complete.
# >>>   2021/05/31 21:46:49 Execution of runSpecialJobTask completed
# >>>   2021/05/31 21:46:49 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# >>>   Stopped: false
# >>>   OriginalData: 3
# >>>   FilteredData: 0.
# >>>   2021/05/31 21:46:49 Process Exiting with Code:  0
# >>>   2021/05/31 21:46:49 All App Insights Logs was send successfully
# >>>
# 2021-05-31T21:46:49Z 127.0.0.1 slots=2 max-slots=2
# 2021-05-31T21:46:50Z launching Custom job
# Streaming azureml-logs/75_job_post-tvmps_447b7d88c5a25e1abf12dfe3ceaf19b6180fbfba013d8d9d61155442bce55907_d.txt
# ===============================================================================================================
# [2021-05-31T21:47:03.875897] Entering job release
# [2021-05-31T21:47:05.113590] Starting job release
# [2021-05-31T21:47:05.117811] Logging experiment finalizing status in history service.
# [2021-05-31T21:47:05.118026] job release stage : upload_datastore starting...
# Starting the daemon thread to refresh tokens in background for process with pid = 162
# [2021-05-31T21:47:05.120798] job release stage : start importing azureml.history._tracking in run_history_release.
# [2021-05-31T21:47:05.120859] job release stage : execute_job_release starting...
# [2021-05-31T21:47:05.128604] job release stage : copy_batchai_cached_logs starting...
# [2021-05-31T21:47:05.129539] job release stage : copy_batchai_cached_logs completed...
# [2021-05-31T21:47:05.129818] Entering context manager injector.
# [2021-05-31T21:47:05.147731] job release stage : upload_datastore completed...
# [2021-05-31T21:47:05.260466] job release stage : execute_job_release completed...
# [2021-05-31T21:47:05.272223] job release stage : send_run_telemetry starting...
# [2021-05-31T21:47:05.405486] get vm size and vm region successfully.
# [2021-05-31T21:47:05.562034] get compute meta data successfully.
# [2021-05-31T21:47:05.784708] post artifact meta request successfully.
# [2021-05-31T21:47:05.832107] upload compute record artifact successfully.
# [2021-05-31T21:47:05.832211] job release stage : send_run_telemetry completed...
# [2021-05-31T21:47:05.832622] Job release is complete
#
# StepRun(Train and Register Model) Execution Summary
# ====================================================
# StepRun( Train and Register Model ) Status: Finished
# {'runId': '9e390739-6b65-41c0-9433-b3f02912b5b9', 'target': 'azCompCluster', 'status': 'Completed', 'startTimeUtc': '2021-05-31T21:46:44.619119Z', 'endTimeUtc': '2021-05-31T21:47:15.339578Z', 'properties': {'ContentSnapshotId': '4d0f18fe-1ee4-465e-8c0b-a41eb7f5561c', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': 'be431421-53be-439b-8de2-78eb09f875e1', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': 'f1811279', 'azureml.pipelinerunid': '8fda1c0c-35c0-400b-bba6-39f268c22c6a', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [], 'outputDatasets': [], 'runDefinition': {'script': 'train_diabetes.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--training-folder', '$AZUREML_DATAREFERENCE_prepped_data_folder'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'azCompCluster', 'dataReferences': {'prepped_data_folder': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/161ac072-e7b6-4525-9af1-36d3979aee4a/prepped_data_folder', 'pathOnCompute': None, 'overwrite': False}}, 'data': {}, 'outputData': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'diabetes-pipeline-env', 'version': '1', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['azureml-defaults~=1.27.0', 'azureml-dataprep[pandas]', 'pyarrow']}, 'scikit-learn', 'ipykernel', 'matplotlib', 'pandas', 'pip'], 'name': 'azureml_28b0d742a4cb5c02a5befb218632cd1a'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210301.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'dockerContext': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': False, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': None, 'imageVersion': None, 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None, 'virtualClusterArmId': None, 'tensorboardLogDirectory': None, 'sshPublicKey': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'pyTorch': {'communicationBackend': 'nccl', 'processCount': None}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': False, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'commandReturnCodeConfig': {'returnCode': 'Zero', 'successfulReturnCodes': []}, 'environmentVariables': {}, 'applicationEndpoints': {}}, 'logFiles': {'azureml-logs/55_azureml-execution-tvmps_447b7d88c5a25e1abf12dfe3ceaf19b6180fbfba013d8d9d61155442bce55907_d.txt': 'https://amlrevision3565263528.blob.core.windows.net/azureml/ExperimentRun/dcid.9e390739-6b65-41c0-9433-b3f02912b5b9/azureml-logs/55_azureml-execution-tvmps_447b7d88c5a25e1abf12dfe3ceaf19b6180fbfba013d8d9d61155442bce55907_d.txt?sv=2019-02-02&sr=b&sig=hN8YbdO7COkV5jhdwKm4ylDMlFfR0CObPCJ5DQ ...
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '8fda1c0c-35c0-400b-bba6-39f268c22c6a', 'status': 'Completed', 'startTimeUtc': '2021-05-31T21:30:51.881222Z', 'endTimeUtc': '2021-05-31T21:47:17.24936Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://amlrevision3565263528.blob.core.windows.net/azureml/ExperimentRun/dcid.8fda1c0c-35c0-400b-bba6-39f268c22c6a/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=suoAGJ0SWPH1SSHrWFf84Q0AX%2F1v7yUrt5lRdlhV%2FvE%3D&st=2021-05-31T21%3A20%3A55Z&se=2021-06-01T05%3A30%3A55Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://amlrevision3565263528.blob.core.windows.net/azureml/ExperimentRun/dcid.8fda1c0c-35c0-400b-bba6-39f268c22c6a/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=XGQIIrM1sTzU2bFuh%2FZBsZzFcu89OPM4HxRX6FsDxz8%3D&st=2021-05-31T21%3A20%3A55Z&se=2021-06-01T05%3A30%3A55Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://amlrevision3565263528.blob.core.windows.net/azureml/ExperimentRun/dcid.8fda1c0c-35c0-400b-bba6-39f268c22c6a/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=i225TLuW4nn8LDFUMQTgK%2BWxlwWFEsGGV3cwj6eWe7A%3D&st=2021-05-31T21%3A20%3A55Z&se=2021-06-01T05%3A30%3A55Z&sp=r'}, 'submittedBy': 'Harsh Vardhan'}
# 'Finished'

# %% [markdown]
# A graphical representation of the pipeline experiment will be displayed in the widget as it runs. Keep an eye on the kernel indicator at the top right of the page, when it turns from **&#9899;** to **&#9711;**, the code has finished running. You can also monitor pipeline runs in the **Experiments** page in [Azure Machine Learning studio](https://ml.azure.com).
#
# When the pipeline has finished, you can examine the metrics recorded by it's child runs.

# %%
for run in pipeline_run.get_children():
    print(run.name, ':')
    metrics = run.get_metrics()
    for metric_name in metrics:
        print('\t',metric_name, ":", metrics[metric_name])
# Out:
# Train and Register Model :
# 	 Accuracy : 0.8991111111111111
# 	 AUC : 0.8837662504280213
# 	 ROC : aml://artifactId/ExperimentRun/dcid.9e390739-6b65-41c0-9433-b3f02912b5b9/ROC_1622497614.png
# Prepare Data :
# 	 raw_rows : 15000
# 	 processed_rows : 15000

# %% [markdown]
# Assuming the pipeline was successful, a new model should be registered with a *Training context* tag indicating it was trained in a pipeline. Run the following code to verify this.

# %%
from azureml.core import Model

for model in Model.list(ws):
    print(model.name, 'version:', model.version)
    for tag_name in model.tags:
        tag = model.tags[tag_name]
        print ('\t',tag_name, ':', tag)
    for prop_name in model.properties:
        prop = model.properties[prop_name]
        print ('\t',prop_name, ':', prop)
    print('\n')
# Out:
# diabetes_model version: 8
# 	 Training context : Pipeline
# 	 AUC : 0.8837662504280213
# 	 Accuracy : 0.8991111111111111
#
#
# diabetes_model version: 7
# 	 Training context : Compute cluster
# 	 AUC : 0.8806126078458612
# 	 Accuracy : 0.8962222222222223
#
#
# diabetes_model version: 6
# 	 Training context : File dataset
# 	 AUC : 0.8468331741963582
# 	 Accuracy : 0.7793333333333333
#
#
# diabetes_model version: 5
# 	 Training context : Tabular dataset
# 	 AUC : 0.8568509052814499
# 	 Accuracy : 0.7891111111111111
#
#
# diabetes_model version: 4
# 	 Training context : Parameterized script
# 	 AUC : 0.8483198169063138
# 	 Accuracy : 0.774
#
#
# diabetes_model version: 3
# 	 Training context : Script
# 	 AUC : 0.8484929598487486
# 	 Accuracy : 0.774
#
#
# diabetes_model version: 2
# 	 Training context : Parameterized script
# 	 AUC : 0.8483198169063138
# 	 Accuracy : 0.774
#
#
# diabetes_model version: 1
# 	 Training context : Script
# 	 AUC : 0.8484929598487486
# 	 Accuracy : 0.774
#
#
# amlstudio-designer-predict-dia version: 1
# 	 CreatedByAMLStudio : true
#
#
# PipelineTrainedClass version: 1
# 	 CreatedByAMLStudio : true
#
#
# AutoMLcde5d93451 version: 1

# %% [markdown]
# ## Publish the pipeline
#
# After you've created and tested a pipeline, you can publish it as a REST service.

# %%
# Publish the pipeline from the run
published_pipeline = pipeline_run.publish_pipeline(
    name="diabetes-training-pipeline", description="Trains diabetes model", version="1.0")

published_pipeline
# Out:
# Pipeline(Name: diabetes-training-pipeline,
# Id: c474ec35-0e2c-4fb5-80ea-a88ef1bb1c68,
# Status: Active,
# Endpoint: https://westus2.api.azureml.ms/pipelines/v1.0/subscriptions/ecdf148e-e3eb-433a-9970-91b083980992/resourceGroups/aml-resources-2/providers/Microsoft.MachineLearningServices/workspaces/aml-revision/PipelineRuns/PipelineSubmit/c474ec35-0e2c-4fb5-80ea-a88ef1bb1c68)

# %% [markdown]
# Note that the published pipeline has an endpoint, which you can see in the **Endpoints** page (on the **Pipeline Endpoints** tab) in [Azure Machine Learning studio](https://ml.azure.com). You can also find its URI as a property of the published pipeline object:

# %%
rest_endpoint = published_pipeline.endpoint
print(rest_endpoint)
# Out:
# https://westus2.api.azureml.ms/pipelines/v1.0/subscriptions/ecdf148e-e3eb-433a-9970-91b083980992/resourceGroups/aml-resources-2/providers/Microsoft.MachineLearningServices/workspaces/aml-revision/PipelineRuns/PipelineSubmit/c474ec35-0e2c-4fb5-80ea-a88ef1bb1c68

# %% [markdown]
# ## Call the pipeline endpoint
#
# To use the endpoint, client applications need to make a REST call over HTTP. This request must be authenticated, so an authorization header is required. A real application would require a service principal with which to be authenticated, but to test this out, we'll use the authorization header from your current connection to your Azure workspace, which you can get using the following code:

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()
print("Authentication header ready.")
# Out:
# Authentication header ready.

# %% [markdown]
# Now we're ready to call the REST interface. The pipeline runs asynchronously, so we'll get an identifier back, which we can use to track the pipeline experiment as it runs:

# %%
import requests

experiment_name = 'mslearn-diabetes-pipeline'

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": experiment_name})
run_id = response.json()["Id"]
run_id
# Out:
# '447b7250-6117-4aad-8380-6d124989fb0d'

# %% [markdown]
# Since you have the run ID, you can use it to wait for the run to complete.
#
# > **Note**: The pipeline should complete quickly, because each step was configured to allow output reuse. This was done primarily for convenience and to save time in this course. In reality, you'd likely want the first step to run every time in case the data has changed, and trigger the subsequent steps only if the output from step one changes.

# %%
from azureml.pipeline.core.run import PipelineRun

published_pipeline_run = PipelineRun(ws.experiments[experiment_name], run_id)
published_pipeline_run.wait_for_completion(show_output=True)
# Out:
# PipelineRunId: 447b7250-6117-4aad-8380-6d124989fb0d
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/447b7250-6117-4aad-8380-6d124989fb0d?wsid=/subscriptions/ecdf148e-e3eb-433a-9970-91b083980992/resourcegroups/aml-resources-2/workspaces/aml-revision&tid=798d0da9-368e-472e-83b1-e8d76c71d339
# PipelineRun Status: NotStarted
# PipelineRun Status: Running
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '447b7250-6117-4aad-8380-6d124989fb0d', 'status': 'Completed', 'startTimeUtc': '2021-05-31T21:47:26.94444Z', 'endTimeUtc': '2021-05-31T21:47:29.156152Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'Unavailable', 'runType': 'HTTP', 'azureml.parameters': '{}', 'azureml.pipelineid': 'c474ec35-0e2c-4fb5-80ea-a88ef1bb1c68'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://amlrevision3565263528.blob.core.windows.net/azureml/ExperimentRun/dcid.447b7250-6117-4aad-8380-6d124989fb0d/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=Nw86ryvqO%2BEjo%2B%2FIG9VQIkK4HMYJNwtVpvG%2FkUKJGJc%3D&st=2021-05-31T21%3A37%3A29Z&se=2021-06-01T05%3A47%3A29Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://amlrevision3565263528.blob.core.windows.net/azureml/ExperimentRun/dcid.447b7250-6117-4aad-8380-6d124989fb0d/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=nbv4%2BCsV0nysgaeahHMQSHjw7gdznASNOCgQbkdj6hs%3D&st=2021-05-31T21%3A37%3A29Z&se=2021-06-01T05%3A47%3A29Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://amlrevision3565263528.blob.core.windows.net/azureml/ExperimentRun/dcid.447b7250-6117-4aad-8380-6d124989fb0d/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=5U3n90N8%2B%2F6JYaw0lwbGprZXp%2BqI4m%2BurJxRhdQaXyk%3D&st=2021-05-31T21%3A37%3A29Z&se=2021-06-01T05%3A47%3A29Z&sp=r'}, 'submittedBy': 'Harsh Vardhan'}
# 'Finished'

# %% [markdown]
# ## Schedule the Pipeline
#
# Suppose the clinic for the diabetes patients collects new data each week, and adds it to the dataset. You could run the pipeline every week to retrain the model with the new data.

# %%
from azureml.pipeline.core import ScheduleRecurrence, Schedule

# Submit the Pipeline every Monday at 00:00 UTC
recurrence = ScheduleRecurrence(frequency="Week", interval=1, week_days=["Monday"], time_of_day="00:00")
weekly_schedule = Schedule.create(ws, name="weekly-diabetes-training", 
                                  description="Based on time",
                                  pipeline_id=published_pipeline.id, 
                                  experiment_name='mslearn-diabetes-pipeline', 
                                  recurrence=recurrence)
print('Pipeline scheduled.')
# Out:
# Pipeline scheduled.

# %% [markdown]
# You can retrieve the schedules that are defined in the workspace like this:

# %%
schedules = Schedule.list(ws)
schedules
# Out:
# [Pipeline(Name: weekly-diabetes-training,
#  Id: c5eed010-686e-4526-af3d-ed2103ecd4a5,
#  Status: Active,
#  Pipeline Id: c474ec35-0e2c-4fb5-80ea-a88ef1bb1c68,
#  Pipeline Endpoint Id: None,
#  Recurrence Details: Runs at 0:00 on Monday every Week)]

# %% [markdown]
# You can check the latest run like this:

# %%
pipeline_experiment = ws.experiments.get('mslearn-diabetes-pipeline')
latest_run = list(pipeline_experiment.get_runs())[0]

latest_run.get_details()
# Out:
# {'runId': '447b7250-6117-4aad-8380-6d124989fb0d',
#  'status': 'Completed',
#  'startTimeUtc': '2021-05-31T21:47:26.94444Z',
#  'endTimeUtc': '2021-05-31T21:47:29.156152Z',
#  'properties': {'azureml.runsource': 'azureml.PipelineRun',
#   'runSource': 'Unavailable',
#   'runType': 'HTTP',
#   'azureml.parameters': '{}',
#   'azureml.pipelineid': 'c474ec35-0e2c-4fb5-80ea-a88ef1bb1c68'},
#  'inputDatasets': [],
#  'outputDatasets': [],
#  'logFiles': {'logs/azureml/executionlogs.txt': 'https://amlrevision3565263528.blob.core.windows.net/azureml/ExperimentRun/dcid.447b7250-6117-4aad-8380-6d124989fb0d/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=Nw86ryvqO%2BEjo%2B%2FIG9VQIkK4HMYJNwtVpvG%2FkUKJGJc%3D&st=2021-05-31T21%3A37%3A29Z&se=2021-06-01T05%3A47%3A29Z&sp=r',
#   'logs/azureml/stderrlogs.txt': 'https://amlrevision3565263528.blob.core.windows.net/azureml/ExperimentRun/dcid.447b7250-6117-4aad-8380-6d124989fb0d/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=nbv4%2BCsV0nysgaeahHMQSHjw7gdznASNOCgQbkdj6hs%3D&st=2021-05-31T21%3A37%3A29Z&se=2021-06-01T05%3A47%3A29Z&sp=r',
#   'logs/azureml/stdoutlogs.txt': 'https://amlrevision3565263528.blob.core.windows.net/azureml/ExperimentRun/dcid.447b7250-6117-4aad-8380-6d124989fb0d/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=5U3n90N8%2B%2F6JYaw0lwbGprZXp%2BqI4m%2BurJxRhdQaXyk%3D&st=2021-05-31T21%3A37%3A29Z&se=2021-06-01T05%3A47%3A29Z&sp=r'},
#  'submittedBy': 'Harsh Vardhan'}

# %% [markdown]
# This is a simple example, designed to demonstrate the principle. In reality, you could build more sophisticated logic into the pipeline steps - for example, evaluating the model against some test data to calculate a performance metric like AUC or accuracy, comparing the metric to that of any previously registered versions of the model, and only registering the new model if it performs better.
#
# You can use the [Azure Machine Learning extension for Azure DevOps](https://marketplace.visualstudio.com/items?itemName=ms-air-aiagility.vss-services-azureml) to combine Azure ML pipelines with Azure DevOps pipelines (yes, it *is* confusing that they have the same name!) and integrate model retraining into a *continuous integration/continuous deployment (CI/CD)* process. For example you could use an Azure DevOps *build* pipeline to trigger an Azure ML pipeline that trains and registers a model, and when the model is registered it could trigger an Azure Devops *release* pipeline that deploys the model as a web service, along with the application or service that consumes the model.
